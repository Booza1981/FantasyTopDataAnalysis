# %%
#Various functions to try and pull out meaningful conclusions from the data
# at the moment:
# 1. Can work out best combinations of cards for portfolio using current score and previous tournament scores
# 2. Can calculate scores of current entries based on current score and previous tournamnet scores

# Should look to 
# 1. Calculate best combination of cards for various tournament entries using set limitations like cost

# %%
import os

print("Current Working Directory:", os.getcwd())
os.chdir(r'C:\Users\beuzi\OneDrive\Jupyter Notebooks\FantasyTop')
# Out:
# Current Working Directory: C:\Users\beuzi

# %% [markdown]
# ## Imports and Setup

# %%
import os
import re
import pandas as pd
from datetime import datetime
from tqdm import tqdm
from itertools import combinations


# Constants
DATA_FOLDER = r'C:\Users\beuzi\OneDrive\Jupyter Notebooks\FantasyTop\data'

TOURNAMENT_COLUMNS = [
    'Main 12', 'Main 11', 'Main 10', 'Main 9', 'Main 8', 'Main 7', 'Main 5', 'Main 4'
]
ALL_SCORES = [
    'hero_fantasy_score', 'Main 12','Main 11', 'Main 10', 'Main 9', 'Main 8', 'Main 7', 'Main 6 *Sat/Sun Only*', 
    'Main 5', 'All Rarities | 22 days', 'Main 4', 'Main 3', 'Common Only ✳️ Capped 20 🌟', 
    'Rare Only 💠', 'Main 2', 'Main 1', 'Flash Tournament', 'Average', 'Main_Tournaments_Ave', 'Main_Last_4_Ave'
]

# Functions

def get_latest_csv_files(folder_path):
    csv_files = {}
    pattern = re.compile(r'^(.*)_(\d{6}_\d{4})\.csv$')
    
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.csv'):
            match = pattern.match(file_name)
            if match:
                prefix = match.group(1)
                timestamp_str = match.group(2)
                try:
                    timestamp = datetime.strptime(timestamp_str, '%y%m%d_%H%M')
                    if prefix not in csv_files or timestamp > csv_files[prefix][1]:
                        csv_files[prefix] = (file_name, timestamp)
                except Exception as e:
                    print(f"Error processing file {file_name}: {e}")
    return {prefix: os.path.join(folder_path, file_name) for prefix, (file_name, _) in csv_files.items()}

def import_latest_csv_files(folder_path):
    latest_files = get_latest_csv_files(folder_path)
    return {prefix: pd.read_csv(file_path) for prefix, file_path in latest_files.items()}

def calculate_tournament_averages(df):
    if 'Name' in df.columns and 'Handle' in df.columns:
        numeric_df = df.drop(['Name', 'Handle'], axis=1).apply(pd.to_numeric, errors='coerce')
        df['Average'] = numeric_df.mean(axis=1)
        df['Main_Tournaments_Ave'] = numeric_df[TOURNAMENT_COLUMNS].mean(axis=1)
        df['Main_Last_4_Ave'] = numeric_df[TOURNAMENT_COLUMNS[:4]].mean(axis=1)
    else:
        raise KeyError("Columns 'Name' and 'Handle' not found in the DataFrame")
    return df

def reorder_basic_hero_stats(df):
    columns_order = ['current_rank', 'hero_name', 'hero_handle'] + \
        [col for col in df.columns if col not in ['current_rank', 'hero_name', 'hero_handle']]
    return df[columns_order]

def merge_dataframes(dataframes):
    # Checking 'tournament_scores' DataFrame
    print("Checking 'tournament_scores' DataFrame:")
    if 'Handle' in dataframes['tournament_scores'].columns:
        print(" - 'Handle' found in 'tournament_scores'.")
    else:
        print(" - ERROR: 'Handle' NOT found in 'tournament_scores'.")
        print("Columns:", dataframes['tournament_scores'].columns)
        print(dataframes['tournament_scores'].head())
        return

    # Merging dataframes
    merged_supply_listings = dataframes['hero_card_supply'].merge(dataframes['listings'], on='hero_id', how='left')
    merged_with_basic_hero_stats = dataframes['basic_hero_stats'].merge(merged_supply_listings, on='hero_handle', how='left')
    merged_df = merged_with_basic_hero_stats.merge(dataframes['last_trades'], on='hero_id', how='left')
    
    # Check before final merge
    print("Checking columns before final merge with 'tournament_scores':")
    print("Columns in 'merged_df':", merged_df.columns)
    print("Columns in 'tournament_scores':", dataframes['tournament_scores'].columns)
    
    # Merge with 'tournament_scores'
    final_merged_df = merged_df.merge(dataframes['tournament_scores'], left_on='hero_handle', right_on='Handle', how='left')

    # Ensure 'hero_handle' is retained
    if 'hero_handle' not in final_merged_df.columns:
        print(" - ERROR: 'hero_handle' was not retained in the final merge. Renaming columns.")
        final_merged_df['hero_handle'] = final_merged_df['Handle']  # Manually set it back if missing
        print("Final columns after renaming:", final_merged_df.columns)

    # Final merge with hero_stats
    final_merged_df = final_merged_df.merge(dataframes['hero_stats'][['hero_handle', 'inflation_degree']], 
                                            left_on='hero_handle', right_on='hero_handle', how='left')

    print("Final merge complete.")
    final_merged_df['hero_id'] = final_merged_df['hero_id'].astype(str)
    return final_merged_df




def save_final_dataframes(final_merged_df, portfolio_scores):
    final_merged_df.to_csv(f'{DATA_FOLDER}/allHeroData.csv', index=False)
    portfolio_scores.to_csv(f'{DATA_FOLDER}/portfolio.csv', index=False)

def process_portfolio_scores(portfolio_df, final_merged_df):
    merged_df = portfolio_df.merge(final_merged_df, on='hero_handle', how='left')
    portfolio_scores = merged_df.drop(['hero_name_y', 'hero_stars_y', 'hero_followers_count_y', 'hero_profile_image_url_y', 'token_id'], axis=1)
    portfolio_scores.columns = [col.replace('_x', '') for col in portfolio_scores.columns]
    
    columns_order = ['hero_name', 'hero_handle'] + [col for col in portfolio_scores.columns if col not in ['hero_name', 'hero_handle']]
    portfolio_scores = portfolio_scores[columns_order]
    
    portfolio_scores['lastSalePrice'] = portfolio_scores.apply(lambda row: row[f'rarity{row["rarity"]}lastSalePrice'], axis=1)
    portfolio_scores['lowestPrice'] = portfolio_scores.apply(lambda row: row[f'rarity{row["rarity"]}_lowest_price'], axis=1)
    portfolio_scores['rarityCount'] = portfolio_scores.apply(lambda row: row[f'rarity{row["rarity"]}Count'], axis=1)
    
    columns_to_drop = [
        'rarity1_lowest_price', 'rarity2_lowest_price', 'rarity3_lowest_price', 'rarity4_lowest_price',
        'rarity1lastSalePrice', 'rarity2lastSalePrice', 'rarity3lastSalePrice', 'rarity4lastSalePrice',
        'rarity1Count', 'rarity2Count', 'rarity3Count', 'rarity4Count',
        'rarity1_order_count', 'rarity2_order_count', 'rarity3_order_count', 'rarity4_order_count',
        'rarity1lastSaleTime', 'rarity2lastSaleTime', 'rarity3lastSaleTime', 'rarity4lastSaleTime'
    ]
    portfolio_scores = portfolio_scores.drop(columns=columns_to_drop)
    
    for col in ALL_SCORES:
        portfolio_scores[col] = pd.to_numeric(portfolio_scores[col], errors='coerce')
        portfolio_scores[col] = portfolio_scores.apply(lambda row: row[col] * 1.5 if row['hero_rarity_index'].endswith('3') else row[col], axis=1)
    
    return portfolio_scores

# Main Execution

def main():
    dataframes = import_latest_csv_files(DATA_FOLDER)
    dataframes['tournament_scores'] = calculate_tournament_averages(dataframes['tournament_scores'])
    dataframes['basic_hero_stats'] = reorder_basic_hero_stats(dataframes['basic_hero_stats'])
    final_merged_df = merge_dataframes(dataframes)
    portfolio_scores = process_portfolio_scores(dataframes['portfolio'], final_merged_df)
    save_final_dataframes(final_merged_df, portfolio_scores)

if __name__ == "__main__":
    main()
# Out:
# Checking 'tournament_scores' DataFrame:
#  - 'Handle' found in 'tournament_scores'.
# Checking columns before final merge with 'tournament_scores':
# Columns in 'merged_df': Index(['current_rank', 'hero_name', 'hero_handle', 'views', 'tweet_count',
#        'fantasy_score', 'reach', 'avg_views', 'hero_followers_count',
#        'hero_profile_image_url', 'hero_volume', 'hero_id', 'rarity1Count',
#        'rarity2Count', 'rarity3Count', 'rarity4Count', 'burnedCardsCount',
#        'utilityCount', 'hero_stars', 'rarity1_lowest_price',
#        'rarity2_lowest_price', 'rarity3_lowest_price', 'rarity4_lowest_price',
#        'rarity1_order_count', 'rarity2_order_count', 'rarity3_order_count',
#        'rarity4_order_count', 'rarity1lastSalePrice', 'rarity2lastSalePrice',
#        'rarity3lastSalePrice', 'rarity4lastSalePrice', 'rarity1lastSaleTime',
#        'rarity2lastSaleTime', 'rarity3lastSaleTime', 'rarity4lastSaleTime'],
#       dtype='object')
# Columns in 'tournament_scores': Index(['Unnamed: 0', 'Name', 'Handle', 'Main 12', 'Main 11', 'Main 10',
#        'Main 9', 'Main 8', 'Main 7', 'Main 6 *Sat/Sun Only*', 'Main 5',
#        'All Rarities | 22 days', 'Main 4', 'Main 3',
#        'Common Only ✳️ Capped 15 🌟', 'Rare Only 💠',
#        'Common Only ✳️ Capped 20 🌟', 'Main 2', 'Main 1', 'Flash Tournament',
#        'hero_handle', 'Average', 'Main_Tournaments_Ave', 'Main_Last_4_Ave'],
#       dtype='object')
#  - ERROR: 'hero_handle' was not retained in the final merge. Renaming columns.
# Final columns after renaming: Index(['current_rank', 'hero_name', 'hero_handle_x', 'views', 'tweet_count',
#        'fantasy_score', 'reach', 'avg_views', 'hero_followers_count',
#        'hero_profile_image_url', 'hero_volume', 'hero_id', 'rarity1Count',
#        'rarity2Count', 'rarity3Count', 'rarity4Count', 'burnedCardsCount',
#        'utilityCount', 'hero_stars', 'rarity1_lowest_price',
#        'rarity2_lowest_price', 'rarity3_lowest_price', 'rarity4_lowest_price',
#        'rarity1_order_count', 'rarity2_order_count', 'rarity3_order_count',
#        'rarity4_order_count', 'rarity1lastSalePrice', 'rarity2lastSalePrice',
#        'rarity3lastSalePrice', 'rarity4lastSalePrice', 'rarity1lastSaleTime',
#        'rarity2lastSaleTime', 'rarity3lastSaleTime', 'rarity4lastSaleTime',
#        'Unnamed: 0', 'Name', 'Handle', 'Main 12', 'Main 11', 'Main 10',
#        'Main 9', 'Main 8', 'Main 7', 'Main 6 *Sat/Sun Only*', 'Main 5',
#        'All Rarities | 22 days', 'Main 4', 'Main 3',
#        'Common Only ✳️ Capped 15 🌟', 'Rare Only 💠',
#        'Common Only ✳️ Capped 20 🌟', 'Main 2', 'Main 1', 'Flash Tournament',
#        'hero_handle_y', 'Average', 'Main_Tournaments_Ave', 'Main_Last_4_Ave',
#        'hero_handle'],
#       dtype='object')
# Final merge complete.

# %%
dataframes = import_latest_csv_files(DATA_FOLDER)
dataframes['basic_hero_stats']
# Out:
#      current_rank               hero_name      hero_handle     views  \
# 0               1                    greg  greg16676935420  81523319
# 1               2   GBH 🦁☝️ Remilio | ᚱᚹᛟ           xbtGBH  23941798
# 2               3          wallstreetbets   wallstreetbets  38745662
# 3               4        mitch (rtrd/acc)        idrawline   5602370
# 4               5                based16z         based16z   3835380
# ..            ...                     ...              ...       ...
# 182           183  Pentoshi 🐧 euroPeng 🇪🇺         Pentosh1         0
# 183           183         Tom Schmidt ＞|＜      tomhschmidt         0
# 184           183                natealex      natealexnft         0
# 185           183                    Kofi           0xKofi         0
# 186           183               Size Chad         SizeChad         0
#
#      tweet_count  fantasy_score       reach      avg_views  \
# 0            117    1000.000000  286.803798  696780.506403
# 1             74     959.813585  467.486147  323537.812826
# 2            194     955.465391  101.985589  199719.909273
# 3            125     939.614744  105.854892   44818.961453
# 4            267     916.626785   57.048130   14364.719070
# ..           ...            ...         ...            ...
# 182            0       0.000000    0.000000       0.000000
# 183            0       0.000000    0.000000       0.000000
# 184            0       0.000000    0.000000       0.000000
# 185            0       0.000000    0.000000       0.000000
# 186            0       0.000000    0.000000       0.000000
#
#      hero_followers_count                             hero_profile_image_url  \
# 0                 1017227  https://pbs.twimg.com/profile_images/158101430...
# 1                  142979  https://pbs.twimg.com/profile_images/177972188...
# 2                  810707  https://pbs.twimg.com/profile_images/181575487...
# 3                   65075  https://pbs.twimg.com/profile_images/177494222...
# 4                   35984  https://pbs.twimg.com/profile_images/179782076...
# ..                    ...                                                ...
# 182                800562  https://pbs.twimg.com/profile_images/176736682...
# 183                 34321  https://pbs.twimg.com/profile_images/177372148...
# 184                178429  https://pbs.twimg.com/profile_images/174301093...
# 185                 32354  https://pbs.twimg.com/profile_images/138786910...
# 186                 91321  https://pbs.twimg.com/profile_images/159688870...
#
#      hero_volume
# 0     212.246551
# 1     174.187213
# 2      16.161170
# 3       0.000000
# 4      77.616767
# ..           ...
# 182    29.874844
# 183   273.743174
# 184   167.663217
# 185    55.854240
# 186    27.008589
#
# [187 rows x 11 columns]

# %%
merged_supply_listings = dataframes['hero_card_supply'].merge(dataframes['listings'], on='hero_id', how='left')
columns_to_drop = ['hero_name', 'hero_followers_count', 'current_rank', 'previous_rank', 'views', 'fantasy_score']
merged_supply_listings = merged_supply_listings.drop(columns=[col for col in columns_to_drop if col in merged_supply_listings.columns])

# %%
merged_with_basic_hero_stats = dataframes['basic_hero_stats'].merge(merged_supply_listings, on='hero_handle', how='left')

# %%
 merged_with_basic_hero_stats
# Out:
#      current_rank               hero_name      hero_handle     views  \
# 0               1                    greg  greg16676935420  81523319
# 1               2   GBH 🦁☝️ Remilio | ᚱᚹᛟ           xbtGBH  23941798
# 2               3          wallstreetbets   wallstreetbets  38745662
# 3               4        mitch (rtrd/acc)        idrawline   5602370
# 4               5                based16z         based16z   3835380
# ..            ...                     ...              ...       ...
# 182           183  Pentoshi 🐧 euroPeng 🇪🇺         Pentosh1         0
# 183           183         Tom Schmidt ＞|＜      tomhschmidt         0
# 184           183                natealex      natealexnft         0
# 185           183                    Kofi           0xKofi         0
# 186           183               Size Chad         SizeChad         0
#
#      tweet_count  fantasy_score       reach      avg_views  \
# 0            117    1000.000000  286.803798  696780.506403
# 1             74     959.813585  467.486147  323537.812826
# 2            194     955.465391  101.985589  199719.909273
# 3            125     939.614744  105.854892   44818.961453
# 4            267     916.626785   57.048130   14364.719070
# ..           ...            ...         ...            ...
# 182            0       0.000000    0.000000       0.000000
# 183            0       0.000000    0.000000       0.000000
# 184            0       0.000000    0.000000       0.000000
# 185            0       0.000000    0.000000       0.000000
# 186            0       0.000000    0.000000       0.000000
#
#      hero_followers_count                             hero_profile_image_url  \
# 0                 1017227  https://pbs.twimg.com/profile_images/158101430...
# 1                  142979  https://pbs.twimg.com/profile_images/177972188...
# 2                  810707  https://pbs.twimg.com/profile_images/181575487...
# 3                   65075  https://pbs.twimg.com/profile_images/177494222...
# 4                   35984  https://pbs.twimg.com/profile_images/179782076...
# ..                    ...                                                ...
# 182                800562  https://pbs.twimg.com/profile_images/176736682...
# 183                 34321  https://pbs.twimg.com/profile_images/177372148...
# 184                178429  https://pbs.twimg.com/profile_images/174301093...
# 185                 32354  https://pbs.twimg.com/profile_images/138786910...
# 186                 91321  https://pbs.twimg.com/profile_images/159688870...
#
#      ...  utilityCount  hero_stars  rarity1_lowest_price  \
# 0    ...           8.0         7.0                   NaN
# 1    ...           8.0         7.0                   NaN
# 2    ...          14.0         7.0                   NaN
# 3    ...           NaN         NaN                   NaN
# 4    ...           4.0         7.0                   NaN
# ..   ...           ...         ...                   ...
# 182  ...          24.0         2.0                   NaN
# 183  ...          30.0         2.0                  0.59
# 184  ...          10.0         2.0                   NaN
# 185  ...          28.0         2.0                   NaN
# 186  ...          35.0         3.0                  1.00
#
#      rarity2_lowest_price  rarity3_lowest_price  rarity4_lowest_price  \
# 0                 12.0000                1.6500              0.380000
# 1                     NaN                   NaN              0.492970
# 2                     NaN                1.5000              0.230000
# 3                     NaN                   NaN                   NaN
# 4                     NaN                0.9000              0.169000
# ..                    ...                   ...                   ...
# 182                0.6850                0.1330              0.025900
# 183                0.1500                0.0299              0.006995
# 184                0.1384                0.0300              0.006800
# 185                0.1400                0.0269              0.006980
# 186                0.2200                0.0499              0.008890
#
#      rarity1_order_count  rarity2_order_count  rarity3_order_count  \
# 0                    NaN                  1.0                  1.0
# 1                    NaN                  0.0                  0.0
# 2                    NaN                  NaN                  2.0
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  2.0
# ..                   ...                  ...                  ...
# 182                  NaN                  1.0                  3.0
# 183                  1.0                  1.0                  6.0
# 184                  0.0                  1.0                  2.0
# 185                  NaN                  4.0                  4.0
# 186                  1.0                  3.0                  3.0
#
#      rarity4_order_count
# 0                    4.0
# 1                    6.0
# 2                    5.0
# 3                    NaN
# 4                    6.0
# ..                   ...
# 182                 16.0
# 183                  6.0
# 184                 20.0
# 185                 13.0
# 186                 51.0
#
# [187 rows x 27 columns]

# %%
merged_df = merged_with_basic_hero_stats.merge(dataframes['last_trades'], on='hero_id', how='left')
final_merged_df = merged_df.merge(dataframes['tournament_scores'], left_on='hero_handle', right_on='Handle', how='left')
final_merged_df = final_merged_df.drop(columns=['Name', 'Handle'])

# Merge with hero_stats to include inflation_degree
final_merged_df = final_merged_df.merge(dataframes['hero_stats'][['hero_handle', 'inflation_degree']], 
                                        left_on='hero_handle', right_on='hero_handle', how='left')


final_merged_df['hero_id'] = final_merged_df['hero_id'].astype(str)
final_merged_df
# Out:
#      current_rank               hero_name      hero_handle     views  \
# 0               1                    greg  greg16676935420  81523319
# 1               2   GBH 🦁☝️ Remilio | ᚱᚹᛟ           xbtGBH  23941798
# 2               3          wallstreetbets   wallstreetbets  38745662
# 3               4        mitch (rtrd/acc)        idrawline   5602370
# 4               5                based16z         based16z   3835380
# ..            ...                     ...              ...       ...
# 182           183  Pentoshi 🐧 euroPeng 🇪🇺         Pentosh1         0
# 183           183         Tom Schmidt ＞|＜      tomhschmidt         0
# 184           183                natealex      natealexnft         0
# 185           183                    Kofi           0xKofi         0
# 186           183               Size Chad         SizeChad         0
#
#      tweet_count  fantasy_score       reach      avg_views  \
# 0            117    1000.000000  286.803798  696780.506403
# 1             74     959.813585  467.486147  323537.812826
# 2            194     955.465391  101.985589  199719.909273
# 3            125     939.614744  105.854892   44818.961453
# 4            267     916.626785   57.048130   14364.719070
# ..           ...            ...         ...            ...
# 182            0       0.000000    0.000000       0.000000
# 183            0       0.000000    0.000000       0.000000
# 184            0       0.000000    0.000000       0.000000
# 185            0       0.000000    0.000000       0.000000
# 186            0       0.000000    0.000000       0.000000
#
#      hero_followers_count                             hero_profile_image_url  \
# 0                 1017227  https://pbs.twimg.com/profile_images/158101430...
# 1                  142979  https://pbs.twimg.com/profile_images/177972188...
# 2                  810707  https://pbs.twimg.com/profile_images/181575487...
# 3                   65075  https://pbs.twimg.com/profile_images/177494222...
# 4                   35984  https://pbs.twimg.com/profile_images/179782076...
# ..                    ...                                                ...
# 182                800562  https://pbs.twimg.com/profile_images/176736682...
# 183                 34321  https://pbs.twimg.com/profile_images/177372148...
# 184                178429  https://pbs.twimg.com/profile_images/174301093...
# 185                 32354  https://pbs.twimg.com/profile_images/138786910...
# 186                 91321  https://pbs.twimg.com/profile_images/159688870...
#
#      ...  All Rarities | 22 days Main 4  Main 3  Common Only ✳️ Capped 15 🌟  \
# 0    ...                     955    949     862                         900
# 1    ...                     986    930     992                       1,000
# 2    ...                     NaN    NaN     NaN                         NaN
# 3    ...                     NaN    NaN     NaN                         NaN
# 4    ...                     860    795     882                         795
# ..   ...                     ...    ...     ...                         ...
# 182  ...                     689    713     771                         482
# 183  ...                     148     88     115                         213
# 184  ...                      90    139     131                          59
# 185  ...                     363    657     225                          26
# 186  ...                     298    345     462                         235
#
#      Rare Only 💠  Common Only ✳️ Capped 20 🌟  Main 2  Main 1  \
# 0            941                       1,000   1,000     757
# 1            951                         906     951   1,000
# 2            NaN                         NaN     NaN     NaN
# 3            NaN                         NaN     NaN     NaN
# 4            833                         841     793     894
# ..           ...                         ...     ...     ...
# 182          613                         456     502     NaN
# 183          443                         178     213     742
# 184          146                          54      67     116
# 185          442                         723     599     NaN
# 186          487                         398     409     NaN
#
#      Flash Tournament  inflation_degree
# 0                 768          1.152022
# 1               1,000          1.152022
# 2                 NaN               NaN
# 3                 NaN               NaN
# 4                 659          1.219587
# ..                ...               ...
# 182               NaN          3.888415
# 183               632         13.803617
# 184               178         12.469203
# 185               NaN          1.050674
# 186               NaN         20.560143
#
# [187 rows x 52 columns]

# %%
all_heroes_df = pd.read_csv('data/allHeroData.csv', dtype={'hero_id': str})

# %%
all_heroes_df['inflation_degree'].sum()
# Out:
# 1773.4924074390035

# %%
all_heroes_stars_freq = all_heroes_df['hero_stars'].value_counts()
cumulative_sum_reverse = all_heroes_stars_freq.sort_index(ascending=False).cumsum()
cumulative_sum_reverse
# Out:
# hero_stars
# 7     27
# 6     57
# 5     86
# 4    115
# 3    143
# 2    177
# Name: count, dtype: int64

# %% [markdown]
# ## Calculating Best Decks with Scores

# %%
from itertools import combinations
import pandas as pd
from tqdm import tqdm
import pickle  # To save and load precomputed combinations

# Function to precompute all valid combinations and their scores
def precompute_combinations(df, max_stars, max_rarity_3_cards, score_columns):
    valid_combinations = []
    
    for combination in tqdm(combinations(df.index, 5), total=len(list(combinations(df.index, 5)))):
        combination_df = df.loc[list(combination)]
        
        total_stars = combination_df['hero_stars'].sum()
        rarity_3_count = combination_df['hero_rarity_index'].apply(lambda x: str(x).endswith('3')).sum()
        
        # Check if the combination meets the constraints
        hero_names = combination_df['hero_name']
        if (total_stars <= max_stars and rarity_3_count <= max_rarity_3_cards and
            len(set(hero_names)) == len(hero_names)):  # Ensure no duplicate heroes
            scores = {col: combination_df[col].sum() for col in score_columns}
            valid_combinations.append((combination, scores))
    
    return valid_combinations

# Function to find the best decks using precomputed combinations and card quantities
def find_best_decks(precomputed_combos, df, max_decks, score_columns):
    all_decks = {col: [] for col in score_columns}
    card_quantities = df['cards_number'].copy()

    for _ in range(max_decks):
        best_combination = {col: None for col in score_columns}
        best_scores = {col: 0 for col in score_columns}
        
        for combo_indices, scores in precomputed_combos:
            # Check if all cards in the combination are available in sufficient quantity
            if all(card_quantities[idx] > 0 for idx in combo_indices):
                for col in score_columns:
                    current_score = scores[col]
                    
                    # Update the best combination for each score column if the current one is better
                    if current_score > best_scores[col]:
                        best_combination[col] = combo_indices
                        best_scores[col] = current_score
        
        # If a valid combination is found, add it to the list of decks
        for col in score_columns:
            if best_combination[col] is not None:
                all_decks[col].append(df.loc[list(best_combination[col])])
                # Update the quantities of the used cards
                for idx in best_combination[col]:
                    card_quantities[idx] -= 1
            else:
                print(f"No more valid combinations found for {col}. Stopping.")
                return all_decks
    
    return all_decks

# Function to filter out already used cards
def filter_used_cards(combinations, used_cards):
    filtered_combos = []
    for combo_indices, scores in combinations:
        if not any(card in used_cards for card in combo_indices):
            filtered_combos.append((combo_indices, scores))
    return filtered_combos

# Load portfolio_scores
portfolio_scores = pd.read_csv('data/portfolio.csv')

# Parameters for Silver Tournament
max_stars = 22
max_rarity_3_cards = 3
max_decks = 4  # Number of decks you want to generate for Silver Tournament
score_columns = ['Main_Last_4_Ave']  # Only focusing on 'Main_Last_4_Ave'

# Precompute all valid combinations and their scores
precomputed_combos_silver = precompute_combinations(portfolio_scores, max_stars, max_rarity_3_cards, score_columns)

# Save precomputed combinations
with open('precomputed_combos_silver.pkl', 'wb') as f:
    pickle.dump(precomputed_combos_silver, f)

# Find the best decks for Silver Tournament
best_decks_silver = find_best_decks(precomputed_combos_silver, portfolio_scores, max_decks, score_columns)

# Display the results for each deck in Silver Tournament
for col in best_decks_silver:
    for i, deck in enumerate(best_decks_silver[col]):
        print(f"\nBest Combination DataFrame for {col}, Silver Deck {i+1}:")
        print(deck)
        print(f"Total {col} score: {deck[col].sum()}")

# Track used cards from Silver decks
used_cards_silver = set()
for deck in best_decks_silver['Main_Last_4_Ave']:
    used_cards_silver.update(deck.index)
# Out:
# 100%|████████████████████████████████████████████████████████████████████| 5949147/5949147 [1:29:32<00:00, 1107.27it/s]
# Best Combination DataFrame for Main_Last_4_Ave, Silver Deck 1:
#           hero_name    hero_handle  hero_handle.1      hero_rarity_index  \
# 0           DCF GOD         dcfgod         dcfgod  1350996311777161219_3
# 5   _gabrielShapir0       lex_node       lex_node   954015928924057601_3
# 20  zac.eth 🧙🏻‍♂️♦️         zacxbt         zacxbt   886765719391789057_3
# 33          Mercury  TraderMercury  TraderMercury  1180256836416614401_4
# 42      Chumbawamba  chumbawamba22  chumbawamba22  1479247421330837508_4
#
#     cards_number  listed_cards_number  in_deck  gliding_score  card_in_deck  \
# 0              1                    0     True    1038.094843         False
# 5              1                    0     True     845.291605          True
# 20             1                    0     True     625.894136         False
# 33             1                    0     True     478.133645         False
# 42             1                    0     True     376.717765         False
#
#                                           picture_url  ...  Main 1  \
# 0   https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   969.0
# 5   https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   868.5
# 20  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...  1152.0
# 33  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN
# 42  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN
#
#     Flash Tournament  hero_handle_y     Average  Main_Tournaments_Ave  \
# 0              657.0         dcfgod  797.750000            892.500000
# 5              702.0       lex_node  863.083333            894.937500
# 20             795.0         zacxbt  792.750000            802.500000
# 33               NaN  TraderMercury  497.444444            543.571429
# 42               NaN  chumbawamba22  572.750000            551.000000
#
#     Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
# 0           991.875          1.135131       0.094000    0.098900        378.0
# 5           963.000          1.000000       0.099500    0.099990        282.0
# 20          829.125          1.016891       0.032300    0.041500        335.0
# 33          536.000               NaN       0.022900    0.025999        211.0
# 42          549.500          2.418870       0.025499    0.025500        271.0
#
# [5 rows x 57 columns]
# Total Main_Last_4_Ave score: 3869.5
#
# Best Combination DataFrame for Main_Last_4_Ave, Silver Deck 2:
#           hero_name     hero_handle   hero_handle.1      hero_rarity_index  \
# 1              Iced       IcedKnife       IcedKnife            618539620_3
# 3    wallstreetbets  wallstreetbets  wallstreetbets            588569122_4
# 12  Hugo Martingale  HugoMartingale  HugoMartingale  1635676907529285642_3
# 51  kipit | fan/acc         0xKipit         0xKipit   720313843021385728_3
# 58     Tim Copeland    Timccopeland    Timccopeland   953233327238021120_4
#
#     cards_number  listed_cards_number  in_deck  gliding_score  card_in_deck  \
# 1              1                    0     True    1006.658424         False
# 3              1                    0     True     951.583435          True
# 12             1                    0     True     762.363567          True
# 51             1                    0     True     298.771874         False
# 58             4                    0     True     206.785536         False
#
#                                           picture_url  ...  Main 1  \
# 1   https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   853.5
# 3   https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN
# 12  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   592.5
# 51  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   645.0
# 58  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   282.0
#
#     Flash Tournament   hero_handle_y     Average  Main_Tournaments_Ave  \
# 1              903.0       IcedKnife  830.916667            894.375000
# 3                NaN  wallstreetbets  808.000000            907.857143
# 12             658.5  HugoMartingale  620.250000            809.062500
# 51             471.0         0xKipit  615.000000            574.875000
# 58             797.0    Timccopeland  408.333333            481.000000
#
#     Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
# 1           929.625          2.114827       0.145000     0.14650        127.0
# 3           931.000               NaN       0.221000     0.28000         67.0
# 12          834.000         77.281181       0.066000     0.07400        142.0
# 51          456.000          2.266849       0.028500     0.02898        283.0
# 58          408.750          6.253199       0.008511     0.01070       1219.0
#
# [5 rows x 57 columns]
# Total Main_Last_4_Ave score: 3559.375
#
# Best Combination DataFrame for Main_Last_4_Ave, Silver Deck 3:
#        hero_name   hero_handle hero_handle.1      hero_rarity_index  \
# 2           Minh  MINHxDYNASTY  MINHxDYNASTY  1310378599984148480_3
# 13     K A L E O   CryptoKaleo   CryptoKaleo   906234475604037637_4
# 15       PreRich     0xprerich     0xprerich  1585936726370852865_3
# 57         apix🎮      apixtwts      apixtwts  1400381995558047749_3
# 58  Tim Copeland  Timccopeland  Timccopeland   953233327238021120_4
#
#     cards_number  listed_cards_number  in_deck  gliding_score  card_in_deck  \
# 2              1                    0     True     968.333497         False
# 13             2                    0    False     743.462476         False
# 15             1                    0     True     694.033718         False
# 57             1                    0    False     210.801498         False
# 58             4                    0     True     206.785536         False
#
#                                           picture_url  ...  Main 1  \
# 2   https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN
# 13  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN
# 15  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   853.5
# 57  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   927.0
# 58  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   282.0
#
#     Flash Tournament hero_handle_y     Average  Main_Tournaments_Ave  \
# 2                NaN  MINHxDYNASTY  692.250000              748.1250
# 13               NaN   CryptoKaleo  612.500000              610.2500
# 15             490.5     0xprerich  803.000000              791.0625
# 57             565.5      apixtwts  669.500000              630.0000
# 58             797.0  Timccopeland  408.333333              481.0000
#
#     Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
# 2           898.500         23.786385       0.088500     0.08500         66.0
# 13          844.500          1.016891       0.068000     0.06700        626.0
# 15          806.625          1.016891       0.055501     0.06968        161.0
# 57          430.500          1.540522       0.023510     0.02800        167.0
# 58          408.750          6.253199       0.008511     0.01070       1219.0
#
# [5 rows x 57 columns]
# Total Main_Last_4_Ave score: 3388.875
#
# Best Combination DataFrame for Main_Last_4_Ave, Silver Deck 4:
#        hero_name     hero_handle   hero_handle.1      hero_rarity_index  \
# 4         kmoney       kmoney_69       kmoney_69  1404603419101306881_3
# 17      ciniz 👁️     screentimes     screentimes  1093242943127932930_4
# 21           W3Q       Web3Quant       Web3Quant  1518981537307496448_4
# 49          Adam  surfcoderepeat  surfcoderepeat            408488225_3
# 58  Tim Copeland    Timccopeland    Timccopeland   953233327238021120_4
#
#     cards_number  listed_cards_number  in_deck  gliding_score  card_in_deck  \
# 4              1                    0     True     870.128891         False
# 17             3                    1     True     663.021056         False
# 21             1                    0     True     607.452884         False
# 49             1                    0     True     320.248772         False
# 58             4                    0     True     206.785536         False
#
#                                           picture_url  ...  Main 1  \
# 4   https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN
# 17  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   741.0
# 21  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   956.0
# 49  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   894.0
# 58  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   282.0
#
#     Flash Tournament   hero_handle_y     Average  Main_Tournaments_Ave  \
# 4                NaN       kmoney_69  752.062500              851.2500
# 17             639.0     screentimes  591.000000              668.3750
# 21             877.0       Web3Quant  745.944444              689.0000
# 49             564.0  surfcoderepeat  622.750000              559.3125
# 58             797.0    Timccopeland  408.333333              481.0000
#
#     Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
# 4           776.250          3.803958       0.072500     0.09999         90.0
# 17          724.500          1.168913       0.027230     0.03000        349.0
# 21          779.500          1.202696       0.068137     0.08880         86.0
# 49          389.625          1.456066       0.027500     0.02780        179.0
# 58          408.750          6.253199       0.008511     0.01070       1219.0
#
# [5 rows x 57 columns]
# Total Main_Last_4_Ave score: 3078.625
# No more valid combinations found for Main_Last_4_Ave. Stopping.
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 1:
#                     hero_name      hero_handle    hero_handle.1  \
# 9                     jingtao  muzzyvermillion  muzzyvermillion
# 14                    foobar/         0xfoobar         0xfoobar
# 46                     Yano 🟪    JasonYanowitz    JasonYanowitz
# 53  Unipcs (aka 'Bonk Guy') 🎒        theunipcs        theunipcs
# 56               yieldfarming      delucinator      delucinator
#
#         hero_rarity_index  cards_number  listed_cards_number  in_deck  \
# 9   1769641180898131968_4             2                    1     True
# 14  1356386110847377408_3             2                    0     True
# 46           1107518478_4             2                    0     True
# 53  1755899659040555009_4             1                    0     True
# 56  1408762516969201671_3             2                    0     True
#
#     gliding_score  card_in_deck  \
# 9      788.435167         False
# 14     735.926077         False
# 46     337.685630         False
# 53     278.106094         False
# 56     211.958978         False
#
#                                           picture_url  ...  Main 1  \
# 9   https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN
# 14  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   337.5
# 46  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   331.0
# 53  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN
# 56  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   951.0
#
#     Flash Tournament    hero_handle_y     Average  Main_Tournaments_Ave  \
# 9                NaN  muzzyvermillion  795.750000            827.375000
# 14             360.0         0xfoobar  689.000000            672.750000
# 46               0.0    JasonYanowitz  411.944444            507.375000
# 53               NaN        theunipcs  469.222222            509.571429
# 56             975.0      delucinator  695.500000            672.562500
#
#     Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
# 9           822.000          2.385088        0.08300     0.09559         84.0
# 14          561.000          1.016891        0.02990     0.03490        419.0
# 46          453.750         16.472445        0.01260     0.01390       1918.0
# 53          384.750               NaN        0.05050     0.05050        170.0
# 56          382.125          8.009896        0.03401     0.03900        115.0
#
# [5 rows x 57 columns]
# Total Main_Last_4_Ave score: 2603.625
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 2:
#           hero_name    hero_handle  hero_handle.1      hero_rarity_index  \
# 14          foobar/       0xfoobar       0xfoobar  1356386110847377408_3
# 25  _gabrielShapir0       lex_node       lex_node   954015928924057601_4
# 40  zac.eth 🧙🏻‍♂️♦️         zacxbt         zacxbt   886765719391789057_4
# 46           Yano 🟪  JasonYanowitz  JasonYanowitz           1107518478_4
# 56     yieldfarming    delucinator    delucinator  1408762516969201671_3
#
#     cards_number  listed_cards_number  in_deck  gliding_score  card_in_deck  \
# 14             2                    0     True     735.926077         False
# 25             1                    0    False     563.527737         False
# 40             2                    0     True     417.262757         False
# 46             2                    0     True     337.685630         False
# 56             2                    0     True     211.958978         False
#
#                                           picture_url  ...  Main 1  \
# 14  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   337.5
# 25  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   579.0
# 40  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   768.0
# 46  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   331.0
# 56  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   951.0
#
#     Flash Tournament  hero_handle_y     Average  Main_Tournaments_Ave  \
# 14             360.0       0xfoobar  689.000000              672.7500
# 25             468.0       lex_node  575.388889              596.6250
# 40             530.0         zacxbt  528.500000              535.0000
# 46               0.0  JasonYanowitz  411.944444              507.3750
# 56             975.0    delucinator  695.500000              672.5625
#
#     Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
# 14          561.000          1.016891       0.029900      0.0349        419.0
# 25          642.000          1.000000       0.019500      0.0202       1380.0
# 40          552.750          1.016891       0.007512      0.0088       1630.0
# 46          453.750         16.472445       0.012600      0.0139       1918.0
# 56          382.125          8.009896       0.034010      0.0390        115.0
#
# [5 rows x 57 columns]
# Total Main_Last_4_Ave score: 2591.625
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 3:
#           hero_name      hero_handle    hero_handle.1      hero_rarity_index  \
# 28               me   mememe69696969   mememe69696969  1453982860663087107_4
# 39     LilMoonLambo     LilMoonLambo     LilMoonLambo           2593497397_4
# 40  zac.eth 🧙🏻‍♂️♦️           zacxbt           zacxbt   886765719391789057_4
# 45          Ben Roy         benroy__         benroy__  1170153611499720704_4
# 55        KJ Crypto  koreanjewcrypto  koreanjewcrypto   873190778910253056_4
#
#     cards_number  listed_cards_number  in_deck  gliding_score  card_in_deck  \
# 28             2                    0     True     536.533691         False
# 39             1                    0     True     421.545626         False
# 40             2                    0     True     417.262757         False
# 45             1                    0     True     348.327841         False
# 55             2                    0     True     222.517986         False
#
#                                           picture_url  ...  Main 1  \
# 28  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   776.0
# 39  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN
# 40  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   768.0
# 45  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   583.0
# 55  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   621.0
#
#     Flash Tournament    hero_handle_y     Average  Main_Tournaments_Ave  \
# 28             315.0   mememe69696969  574.444444               563.125
# 39               NaN     LilMoonLambo  548.875000               521.125
# 40             530.0           zacxbt  528.500000               535.000
# 45             345.0         benroy__  496.833333               462.750
# 55             432.0  koreanjewcrypto  454.833333               323.000
#
#     Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
# 28           600.25          1.016891       0.015900    0.016800       2126.0
# 39           519.25          1.270261       0.018421    0.025000        310.0
# 40           552.75          1.016891       0.007512    0.008800       1630.0
# 45           429.75          1.000000       0.007200    0.007868       1978.0
# 55           362.00          1.016891       0.008500    0.008590       1404.0
#
# [5 rows x 57 columns]
# Total Main_Last_4_Ave score: 2464.0
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 4:
#       hero_name      hero_handle    hero_handle.1      hero_rarity_index  \
# 9       jingtao  muzzyvermillion  muzzyvermillion  1769641180898131968_4
# 41         cozy   cozymaximalist   cozymaximalist  1475612593830178820_4
# 54     makesy 🟢         0xMakesy         0xMakesy  1416421769561378817_4
# 55    KJ Crypto  koreanjewcrypto  koreanjewcrypto   873190778910253056_4
# 59  Luke Martin   VentureCoinist   VentureCoinist   877728873340956672_4
#
#     cards_number  listed_cards_number  in_deck  gliding_score  card_in_deck  \
# 9              2                    1     True     788.435167         False
# 41             2                    0     True     413.859469         False
# 54             1                    0     True     226.842103         False
# 55             2                    0     True     222.517986         False
# 59             2                    0     True     193.606493         False
#
#                                           picture_url  ...  Main 1  \
# 9   https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN
# 41  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   616.0
# 54  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   599.0
# 55  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   621.0
# 59  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...    64.0
#
#     Flash Tournament    hero_handle_y     Average  Main_Tournaments_Ave  \
# 9                NaN  muzzyvermillion  795.750000               827.375
# 41             719.0   cozymaximalist  486.611111               522.375
# 54             697.0         0xMakesy  413.888889               425.750
# 55             432.0  koreanjewcrypto  454.833333               323.000
# 59             273.0   VentureCoinist  187.611111               211.375
#
#     Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
# 9            822.00          2.385088       0.083000     0.09559         84.0
# 41           495.00         44.410681       0.011300     0.01170        537.0
# 54           414.50          2.452653       0.014805     0.01449       1266.0
# 55           362.00          1.016891       0.008500     0.00859       1404.0
# 59           264.25          4.462720       0.013000     0.01350       1479.0
#
# [5 rows x 57 columns]
# Total Main_Last_4_Ave score: 2357.75
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 5:
#               hero_name     hero_handle   hero_handle.1  \
# 28                   me  mememe69696969  mememe69696969
# 41                 cozy  cozymaximalist  cozymaximalist
# 43  Gabriel Haines.⌐◨-◨   gabrielhaines   gabrielhaines
# 47                  MAX    max_the_plug    max_the_plug
# 59          Luke Martin  VentureCoinist  VentureCoinist
#
#         hero_rarity_index  cards_number  listed_cards_number  in_deck  \
# 28  1453982860663087107_4             2                    0     True
# 41  1475612593830178820_4             2                    0     True
# 43           3159122144_4             4                    0     True
# 47  1526588836536586240_4             2                    0     True
# 59   877728873340956672_4             2                    0     True
#
#     gliding_score  card_in_deck  \
# 28     536.533691         False
# 41     413.859469         False
# 43     366.775560         False
# 47     330.204200         False
# 59     193.606493         False
#
#                                           picture_url  ...  Main 1  \
# 28  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   776.0
# 41  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   616.0
# 43  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   215.0
# 47  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   568.0
# 59  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...    64.0
#
#     Flash Tournament   hero_handle_y     Average  Main_Tournaments_Ave  \
# 28             315.0  mememe69696969  574.444444               563.125
# 41             719.0  cozymaximalist  486.611111               522.375
# 43             110.0   gabrielhaines  407.500000               520.500
# 47             406.0    max_the_plug  474.500000               448.000
# 59             273.0  VentureCoinist  187.611111               211.375
#
#     Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
# 28           600.25          1.016891       0.015900      0.0168       2126.0
# 41           495.00         44.410681       0.011300      0.0117        537.0
# 43           484.25          6.759939       0.008110      0.0090       1575.0
# 47           385.75          1.016891       0.006355      0.0080        675.0
# 59           264.25          4.462720       0.013000      0.0135       1479.0
#
# [5 rows x 57 columns]
# Total Main_Last_4_Ave score: 2229.5
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 6:
#               hero_name    hero_handle  hero_handle.1      hero_rarity_index  \
# 34               CBB0FE         Cbb0fe         Cbb0fe  1703332734603591680_4
# 43  Gabriel Haines.⌐◨-◨  gabrielhaines  gabrielhaines           3159122144_4
# 44        🉐 Crypto Linn    crypto_linn    crypto_linn  1139174563802226688_4
# 47                  MAX   max_the_plug   max_the_plug  1526588836536586240_4
# 48         NFTstats.eth       punk9059       punk9059  1449164448321605632_4
#
#     cards_number  listed_cards_number  in_deck  gliding_score  card_in_deck  \
# 34             1                    0     True     461.241826         False
# 43             4                    0     True     366.775560         False
# 44             1                    0     True     351.123232         False
# 47             2                    0     True     330.204200         False
# 48             2                    0     True     330.017913         False
#
#                                           picture_url  ...  Main 1  \
# 34  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   616.0
# 43  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   215.0
# 44  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   558.0
# 47  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   568.0
# 48  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   765.0
#
#     Flash Tournament  hero_handle_y     Average  Main_Tournaments_Ave  \
# 34             815.0         Cbb0fe  477.555556                413.25
# 43             110.0  gabrielhaines  407.500000                520.50
# 44             162.0    crypto_linn  505.166667                545.25
# 47             406.0   max_the_plug  474.500000                448.00
# 48             482.0       punk9059  529.777778                421.50
#
#     Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
# 34           482.00          2.097936       0.011900    0.012000        982.0
# 43           484.25          6.759939       0.008110    0.009000       1575.0
# 44           484.25          1.000000       0.008290    0.010389       1943.0
# 47           385.75          1.016891       0.006355    0.008000        675.0
# 48           330.50          1.016891       0.009800    0.011490        552.0
#
# [5 rows x 57 columns]
# Total Main_Last_4_Ave score: 2166.75
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 7:
#                                      hero_name    hero_handle  hero_handle.1  \
# 31                                          qw         QwQiao         QwQiao
# 36  █̶̳̘͛̄̃͒̄̃͜█̴͇̱̅͒̅█̵̻̣̝͒̈̄̈͝͝█̴̞̜̻̝͍̂̽͜█̷̢         SHL0MS         SHL0MS
# 43                         Gabriel Haines.⌐◨-◨  gabrielhaines  gabrielhaines
# 48                                NFTstats.eth       punk9059       punk9059
# 60                      Pentoshi 🐧 euroPeng 🇪🇺       Pentosh1       Pentosh1
#
#         hero_rarity_index  cards_number  listed_cards_number  in_deck  \
# 31   712457848874086400_4             1                    0     True
# 36   829482275318484993_4             4                    0     True
# 43           3159122144_4             4                    0     True
# 48  1449164448321605632_4             2                    0     True
# 60  1138993163706753029_4             4                    0     True
#
#     gliding_score  card_in_deck  \
# 31     500.481578         False
# 36     455.964501         False
# 43     366.775560         False
# 48     330.017913         False
# 60       0.000000         False
#
#                                           picture_url  ...  Main 1  \
# 31  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   666.0
# 36  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   277.0
# 43  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   215.0
# 48  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   765.0
# 60  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN
#
#     Flash Tournament  hero_handle_y     Average  Main_Tournaments_Ave  \
# 31             328.0         QwQiao  482.444444                521.75
# 36             229.0         SHL0MS  451.222222                449.00
# 43             110.0  gabrielhaines  407.500000                520.50
# 48             482.0       punk9059  529.777778                421.50
# 60               NaN       Pentosh1  447.812500                337.75
#
#     Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
# 31           568.25          1.202696       0.013003     0.01550        612.0
# 36           407.50          1.067565       0.008890     0.00890       1735.0
# 43           484.25          6.759939       0.008110     0.00900       1575.0
# 48           330.50          1.016891       0.009800     0.01149        552.0
# 60           145.75          3.888415       0.020000     0.02169        429.0
#
# [5 rows x 57 columns]
# Total Main_Last_4_Ave score: 1936.25
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 8:
#                                      hero_name     hero_handle  \
# 30                             Hugo Martingale  HugoMartingale
# 36  █̶̳̘͛̄̃͒̄̃͜█̴͇̱̅͒̅█̵̻̣̝͒̈̄̈͝͝█̴̞̜̻̝͍̂̽͜█̷̢          SHL0MS
# 43                         Gabriel Haines.⌐◨-◨   gabrielhaines
# 52                     travis bickle ⎮ fan/acc  TravisBickle0x
# 60                      Pentoshi 🐧 euroPeng 🇪🇺        Pentosh1
#
#      hero_handle.1      hero_rarity_index  cards_number  listed_cards_number  \
# 30  HugoMartingale  1635676907529285642_4             1                    0
# 36          SHL0MS   829482275318484993_4             4                    0
# 43   gabrielhaines           3159122144_4             4                    0
# 52  TravisBickle0x  1588487175540195328_4             1                    0
# 60        Pentosh1  1138993163706753029_4             4                    0
#
#     in_deck  gliding_score  card_in_deck  \
# 30     True     508.242378         False
# 36     True     455.964501         False
# 43     True     366.775560         False
# 52     True     296.541515         False
# 60     True       0.000000         False
#
#                                           picture_url  ...  Main 1  \
# 30  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   395.0
# 36  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   277.0
# 43  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   215.0
# 52  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   737.0
# 60  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN
#
#     Flash Tournament   hero_handle_y     Average  Main_Tournaments_Ave  \
# 30             439.0  HugoMartingale  413.500000               539.375
# 36             229.0          SHL0MS  451.222222               449.000
# 43             110.0   gabrielhaines  407.500000               520.500
# 52             607.0  TravisBickle0x  437.222222               352.375
# 60               NaN        Pentosh1  447.812500               337.750
#
#     Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
# 30           556.00         77.281181       0.014400    0.016700        898.0
# 36           407.50          1.067565       0.008890    0.008900       1735.0
# 43           484.25          6.759939       0.008110    0.009000       1575.0
# 52           298.00          1.827674       0.006506    0.007539       1448.0
# 60           145.75          3.888415       0.020000    0.021690        429.0
#
# [5 rows x 57 columns]
# Total Main_Last_4_Ave score: 1891.5
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 9:
#                                      hero_name  hero_handle hero_handle.1  \
# 35                             jez (blast era)   izebel_eth    izebel_eth
# 36  █̶̳̘͛̄̃͒̄̃͜█̴͇̱̅͒̅█̵̻̣̝͒̈̄̈͝͝█̴̞̜̻̝͍̂̽͜█̷̢       SHL0MS        SHL0MS
# 38                                    Sisyphus   0xSisyphus    0xSisyphus
# 50                                 Taiki Maeda  TaikiMaeda2   TaikiMaeda2
# 60                      Pentoshi 🐧 euroPeng 🇪🇺     Pentosh1      Pentosh1
#
#         hero_rarity_index  cards_number  listed_cards_number  in_deck  \
# 35   815322092627333121_4             1                    0     True
# 36   829482275318484993_4             4                    0     True
# 38  1366930865574584323_4             1                    0     True
# 50  1064421325186359296_4             2                    0     True
# 60  1138993163706753029_4             4                    0     True
#
#     gliding_score  card_in_deck  \
# 35     461.151803         False
# 36     455.964501         False
# 38     426.336721         False
# 50     302.723982         False
# 60       0.000000         False
#
#                                           picture_url  ...  Main 1  \
# 35  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   506.0
# 36  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   277.0
# 38  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   729.0
# 50  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   505.0
# 60  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN
#
#     Flash Tournament hero_handle_y     Average  Main_Tournaments_Ave  \
# 35             576.0    izebel_eth  406.277778               407.375
# 36             229.0        SHL0MS  451.222222               449.000
# 38             646.0    0xSisyphus  492.722222               449.375
# 50             474.0   TaikiMaeda2  355.277778               368.000
# 60               NaN      Pentosh1  447.812500               337.750
#
#     Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
# 35           388.50          9.648354       0.010800    0.008500        786.0
# 36           407.50          1.067565       0.008890    0.008900       1735.0
# 38           406.75          2.418870       0.013000    0.012900        461.0
# 50           357.25         11.219246       0.005311    0.007448        977.0
# 60           145.75          3.888415       0.020000    0.021690        429.0
#
# [5 rows x 57 columns]
# Total Main_Last_4_Ave score: 1705.75

# %%
# Load precomputed combinations (instead of recomputing)
with open('precomputed_combos_silver.pkl', 'rb') as f:
    precomputed_combos_silver = pickle.load(f)

# Bronze Tournament: Filter precomputed combinations for those with only rarity 4 cards
def filter_bronze_combinations(precomputed_combos):
    filtered_combos = []
    
    for combo_indices, scores in tqdm(precomputed_combos, desc="Filtering Bronze combinations"):
        combo_rarities = portfolio_scores.loc[list(combo_indices), 'hero_rarity_index']
        
        # Only keep combinations where all cards are rarity 4
        if combo_rarities.apply(lambda x: str(x).endswith('4')).all():
            filtered_combos.append((combo_indices, scores))
    
    return filtered_combos

# Filter out combinations that use Silver cards for Bronze deck calculation
filtered_combos_bronze = filter_used_cards(precomputed_combos_silver, used_cards_silver)

# Apply the rarity 4 filter for Bronze decks
filtered_combos_bronze = filter_bronze_combinations(filtered_combos_bronze)

# Ensure Bronze deck does not exceed star limit
def filter_by_star_limit(combinations, max_stars):
    valid_combinations = []
    for combo_indices, scores in combinations:
        total_stars = portfolio_scores.loc[list(combo_indices), 'hero_stars'].sum()
        if total_stars <= max_stars:
            valid_combinations.append((combo_indices, scores))
    return valid_combinations

# Apply star limit for Bronze
filtered_combos_bronze = filter_by_star_limit(filtered_combos_bronze, 18)

# Find the best decks for Bronze Tournament
best_decks_bronze = find_best_decks(filtered_combos_bronze, portfolio_scores, 10, score_columns)

# Display the results for each deck in Bronze Tournament
for col in best_decks_bronze:
    for i, deck in enumerate(best_decks_bronze[col]):
        print(f"\nBest Combination DataFrame for {col}, Bronze Deck {i+1}:")
        print(deck)
        print(f"Total {col} score: {deck[col].sum()}")
# Out:
# Filtering Bronze combinations: 100%|█████████████████████████████████████████| 503762/503762 [05:12<00:00, 1614.22it/s]
# No more valid combinations found for Main_Last_4_Ave. Stopping.
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 1:
#                     hero_name      hero_handle    hero_handle.1  \
# 9                     jingtao  muzzyvermillion  muzzyvermillion
# 40            zac.eth 🧙🏻‍♂️♦️           zacxbt           zacxbt
# 46                     Yano 🟪    JasonYanowitz    JasonYanowitz
# 53  Unipcs (aka 'Bonk Guy') 🎒        theunipcs        theunipcs
# 55                  KJ Crypto  koreanjewcrypto  koreanjewcrypto
#
#         hero_rarity_index  cards_number  listed_cards_number  in_deck  \
# 9   1769641180898131968_4             2                    1     True
# 40   886765719391789057_4             2                    0     True
# 46           1107518478_4             2                    0     True
# 53  1755899659040555009_4             1                    0     True
# 55   873190778910253056_4             2                    0     True
#
#     gliding_score  card_in_deck  \
# 9      788.435167         False
# 40     417.262757         False
# 46     337.685630         False
# 53     278.106094         False
# 55     222.517986         False
#
#                                           picture_url  ...  Main 1  \
# 9   https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN
# 40  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   768.0
# 46  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   331.0
# 53  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN
# 55  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   621.0
#
#     Flash Tournament    hero_handle_y     Average  Main_Tournaments_Ave  \
# 9                NaN  muzzyvermillion  795.750000            827.375000
# 40             530.0           zacxbt  528.500000            535.000000
# 46               0.0    JasonYanowitz  411.944444            507.375000
# 53               NaN        theunipcs  469.222222            509.571429
# 55             432.0  koreanjewcrypto  454.833333            323.000000
#
#     Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
# 9            822.00          2.385088       0.083000     0.09559         84.0
# 40           552.75          1.016891       0.007512     0.00880       1630.0
# 46           453.75         16.472445       0.012600     0.01390       1918.0
# 53           384.75               NaN       0.050500     0.05050        170.0
# 55           362.00          1.016891       0.008500     0.00859       1404.0
#
# [5 rows x 57 columns]
# Total Main_Last_4_Ave score: 2575.25
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 2:
#           hero_name      hero_handle    hero_handle.1     hero_rarity_index  \
# 25  _gabrielShapir0         lex_node         lex_node  954015928924057601_4
# 39     LilMoonLambo     LilMoonLambo     LilMoonLambo          2593497397_4
# 40  zac.eth 🧙🏻‍♂️♦️           zacxbt           zacxbt  886765719391789057_4
# 46           Yano 🟪    JasonYanowitz    JasonYanowitz          1107518478_4
# 55        KJ Crypto  koreanjewcrypto  koreanjewcrypto  873190778910253056_4
#
#     cards_number  listed_cards_number  in_deck  gliding_score  card_in_deck  \
# 25             1                    0    False     563.527737         False
# 39             1                    0     True     421.545626         False
# 40             2                    0     True     417.262757         False
# 46             2                    0     True     337.685630         False
# 55             2                    0     True     222.517986         False
#
#                                           picture_url  ...  Main 1  \
# 25  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   579.0
# 39  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN
# 40  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   768.0
# 46  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   331.0
# 55  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   621.0
#
#     Flash Tournament    hero_handle_y     Average  Main_Tournaments_Ave  \
# 25             468.0         lex_node  575.388889               596.625
# 39               NaN     LilMoonLambo  548.875000               521.125
# 40             530.0           zacxbt  528.500000               535.000
# 46               0.0    JasonYanowitz  411.944444               507.375
# 55             432.0  koreanjewcrypto  454.833333               323.000
#
#     Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
# 25           642.00          1.000000       0.019500     0.02020       1380.0
# 39           519.25          1.270261       0.018421     0.02500        310.0
# 40           552.75          1.016891       0.007512     0.00880       1630.0
# 46           453.75         16.472445       0.012600     0.01390       1918.0
# 55           362.00          1.016891       0.008500     0.00859       1404.0
#
# [5 rows x 57 columns]
# Total Main_Last_4_Ave score: 2529.75
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 3:
#    hero_name     hero_handle   hero_handle.1      hero_rarity_index  \
# 28        me  mememe69696969  mememe69696969  1453982860663087107_4
# 41      cozy  cozymaximalist  cozymaximalist  1475612593830178820_4
# 45   Ben Roy        benroy__        benroy__  1170153611499720704_4
# 47       MAX    max_the_plug    max_the_plug  1526588836536586240_4
# 54  makesy 🟢        0xMakesy        0xMakesy  1416421769561378817_4
#
#     cards_number  listed_cards_number  in_deck  gliding_score  card_in_deck  \
# 28             2                    0     True     536.533691         False
# 41             2                    0     True     413.859469         False
# 45             1                    0     True     348.327841         False
# 47             2                    0     True     330.204200         False
# 54             1                    0     True     226.842103         False
#
#                                           picture_url  ...  Main 1  \
# 28  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   776.0
# 41  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   616.0
# 45  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   583.0
# 47  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   568.0
# 54  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   599.0
#
#     Flash Tournament   hero_handle_y     Average  Main_Tournaments_Ave  \
# 28             315.0  mememe69696969  574.444444               563.125
# 41             719.0  cozymaximalist  486.611111               522.375
# 45             345.0        benroy__  496.833333               462.750
# 47             406.0    max_the_plug  474.500000               448.000
# 54             697.0        0xMakesy  413.888889               425.750
#
#     Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
# 28           600.25          1.016891       0.015900    0.016800       2126.0
# 41           495.00         44.410681       0.011300    0.011700        537.0
# 45           429.75          1.000000       0.007200    0.007868       1978.0
# 47           385.75          1.016891       0.006355    0.008000        675.0
# 54           414.50          2.452653       0.014805    0.014490       1266.0
#
# [5 rows x 57 columns]
# Total Main_Last_4_Ave score: 2325.25
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 4:
#               hero_name     hero_handle   hero_handle.1  \
# 28                   me  mememe69696969  mememe69696969
# 41                 cozy  cozymaximalist  cozymaximalist
# 43  Gabriel Haines.⌐◨-◨   gabrielhaines   gabrielhaines
# 47                  MAX    max_the_plug    max_the_plug
# 59          Luke Martin  VentureCoinist  VentureCoinist
#
#         hero_rarity_index  cards_number  listed_cards_number  in_deck  \
# 28  1453982860663087107_4             2                    0     True
# 41  1475612593830178820_4             2                    0     True
# 43           3159122144_4             4                    0     True
# 47  1526588836536586240_4             2                    0     True
# 59   877728873340956672_4             2                    0     True
#
#     gliding_score  card_in_deck  \
# 28     536.533691         False
# 41     413.859469         False
# 43     366.775560         False
# 47     330.204200         False
# 59     193.606493         False
#
#                                           picture_url  ...  Main 1  \
# 28  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   776.0
# 41  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   616.0
# 43  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   215.0
# 47  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   568.0
# 59  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...    64.0
#
#     Flash Tournament   hero_handle_y     Average  Main_Tournaments_Ave  \
# 28             315.0  mememe69696969  574.444444               563.125
# 41             719.0  cozymaximalist  486.611111               522.375
# 43             110.0   gabrielhaines  407.500000               520.500
# 47             406.0    max_the_plug  474.500000               448.000
# 59             273.0  VentureCoinist  187.611111               211.375
#
#     Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
# 28           600.25          1.016891       0.015900      0.0168       2126.0
# 41           495.00         44.410681       0.011300      0.0117        537.0
# 43           484.25          6.759939       0.008110      0.0090       1575.0
# 47           385.75          1.016891       0.006355      0.0080        675.0
# 59           264.25          4.462720       0.013000      0.0135       1479.0
#
# [5 rows x 57 columns]
# Total Main_Last_4_Ave score: 2229.5
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 5:
#               hero_name     hero_handle   hero_handle.1  \
# 31                   qw          QwQiao          QwQiao
# 43  Gabriel Haines.⌐◨-◨   gabrielhaines   gabrielhaines
# 44        🉐 Crypto Linn     crypto_linn     crypto_linn
# 48         NFTstats.eth        punk9059        punk9059
# 59          Luke Martin  VentureCoinist  VentureCoinist
#
#         hero_rarity_index  cards_number  listed_cards_number  in_deck  \
# 31   712457848874086400_4             1                    0     True
# 43           3159122144_4             4                    0     True
# 44  1139174563802226688_4             1                    0     True
# 48  1449164448321605632_4             2                    0     True
# 59   877728873340956672_4             2                    0     True
#
#     gliding_score  card_in_deck  \
# 31     500.481578         False
# 43     366.775560         False
# 44     351.123232         False
# 48     330.017913         False
# 59     193.606493         False
#
#                                           picture_url  ...  Main 1  \
# 31  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   666.0
# 43  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   215.0
# 44  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   558.0
# 48  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   765.0
# 59  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...    64.0
#
#     Flash Tournament   hero_handle_y     Average  Main_Tournaments_Ave  \
# 31             328.0          QwQiao  482.444444               521.750
# 43             110.0   gabrielhaines  407.500000               520.500
# 44             162.0     crypto_linn  505.166667               545.250
# 48             482.0        punk9059  529.777778               421.500
# 59             273.0  VentureCoinist  187.611111               211.375
#
#     Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
# 31           568.25          1.202696       0.013003    0.015500        612.0
# 43           484.25          6.759939       0.008110    0.009000       1575.0
# 44           484.25          1.000000       0.008290    0.010389       1943.0
# 48           330.50          1.016891       0.009800    0.011490        552.0
# 59           264.25          4.462720       0.013000    0.013500       1479.0
#
# [5 rows x 57 columns]
# Total Main_Last_4_Ave score: 2131.5
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 6:
#                                      hero_name     hero_handle  \
# 34                                      CBB0FE          Cbb0fe
# 36  █̶̳̘͛̄̃͒̄̃͜█̴͇̱̅͒̅█̵̻̣̝͒̈̄̈͝͝█̴̞̜̻̝͍̂̽͜█̷̢          SHL0MS
# 43                         Gabriel Haines.⌐◨-◨   gabrielhaines
# 48                                NFTstats.eth        punk9059
# 52                     travis bickle ⎮ fan/acc  TravisBickle0x
#
#      hero_handle.1      hero_rarity_index  cards_number  listed_cards_number  \
# 34          Cbb0fe  1703332734603591680_4             1                    0
# 36          SHL0MS   829482275318484993_4             4                    0
# 43   gabrielhaines           3159122144_4             4                    0
# 48        punk9059  1449164448321605632_4             2                    0
# 52  TravisBickle0x  1588487175540195328_4             1                    0
#
#     in_deck  gliding_score  card_in_deck  \
# 34     True     461.241826         False
# 36     True     455.964501         False
# 43     True     366.775560         False
# 48     True     330.017913         False
# 52     True     296.541515         False
#
#                                           picture_url  ...  Main 1  \
# 34  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   616.0
# 36  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   277.0
# 43  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   215.0
# 48  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   765.0
# 52  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   737.0
#
#     Flash Tournament   hero_handle_y     Average  Main_Tournaments_Ave  \
# 34             815.0          Cbb0fe  477.555556               413.250
# 36             229.0          SHL0MS  451.222222               449.000
# 43             110.0   gabrielhaines  407.500000               520.500
# 48             482.0        punk9059  529.777778               421.500
# 52             607.0  TravisBickle0x  437.222222               352.375
#
#     Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
# 34           482.00          2.097936       0.011900    0.012000        982.0
# 36           407.50          1.067565       0.008890    0.008900       1735.0
# 43           484.25          6.759939       0.008110    0.009000       1575.0
# 48           330.50          1.016891       0.009800    0.011490        552.0
# 52           298.00          1.827674       0.006506    0.007539       1448.0
#
# [5 rows x 57 columns]
# Total Main_Last_4_Ave score: 2002.25
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 7:
#                                      hero_name    hero_handle  hero_handle.1  \
# 35                             jez (blast era)     izebel_eth     izebel_eth
# 36  █̶̳̘͛̄̃͒̄̃͜█̴͇̱̅͒̅█̵̻̣̝͒̈̄̈͝͝█̴̞̜̻̝͍̂̽͜█̷̢         SHL0MS         SHL0MS
# 38                                    Sisyphus     0xSisyphus     0xSisyphus
# 43                         Gabriel Haines.⌐◨-◨  gabrielhaines  gabrielhaines
# 60                      Pentoshi 🐧 euroPeng 🇪🇺       Pentosh1       Pentosh1
#
#         hero_rarity_index  cards_number  listed_cards_number  in_deck  \
# 35   815322092627333121_4             1                    0     True
# 36   829482275318484993_4             4                    0     True
# 38  1366930865574584323_4             1                    0     True
# 43           3159122144_4             4                    0     True
# 60  1138993163706753029_4             4                    0     True
#
#     gliding_score  card_in_deck  \
# 35     461.151803         False
# 36     455.964501         False
# 38     426.336721         False
# 43     366.775560         False
# 60       0.000000         False
#
#                                           picture_url  ...  Main 1  \
# 35  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   506.0
# 36  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   277.0
# 38  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   729.0
# 43  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   215.0
# 60  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN
#
#     Flash Tournament  hero_handle_y     Average  Main_Tournaments_Ave  \
# 35             576.0     izebel_eth  406.277778               407.375
# 36             229.0         SHL0MS  451.222222               449.000
# 38             646.0     0xSisyphus  492.722222               449.375
# 43             110.0  gabrielhaines  407.500000               520.500
# 60               NaN       Pentosh1  447.812500               337.750
#
#     Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
# 35           388.50          9.648354        0.01080     0.00850        786.0
# 36           407.50          1.067565        0.00889     0.00890       1735.0
# 38           406.75          2.418870        0.01300     0.01290        461.0
# 43           484.25          6.759939        0.00811     0.00900       1575.0
# 60           145.75          3.888415        0.02000     0.02169        429.0
#
# [5 rows x 57 columns]
# Total Main_Last_4_Ave score: 1832.75

# %%
best_decks_silver
# Out:
# {'Main_Last_4_Ave': [          hero_name    hero_handle  hero_handle.1      hero_rarity_index  \
#   0           DCF GOD         dcfgod         dcfgod  1350996311777161219_3
#   5   _gabrielShapir0       lex_node       lex_node   954015928924057601_3
#   20  zac.eth 🧙🏻‍♂️♦️         zacxbt         zacxbt   886765719391789057_3
#   40  zac.eth 🧙🏻‍♂️♦️         zacxbt         zacxbt   886765719391789057_4
#   42      Chumbawamba  chumbawamba22  chumbawamba22  1479247421330837508_4
#
#       cards_number  listed_cards_number  in_deck  gliding_score  card_in_deck  \
#   0              1                    0     True    1038.094843         False
#   5              1                    0     True     845.291605          True
#   20             1                    0     True     625.894136         False
#   40             2                    0     True     417.262757         False
#   42             1                    0     True     376.717765         False
#
#                                             picture_url  ...  Main 1  \
#   0   https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   969.0
#   5   https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   868.5
#   20  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...  1152.0
#   40  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   768.0
#   42  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN
#
#       Flash Tournament  hero_handle_y     Average  Main_Tournaments_Ave  \
#   0              657.0         dcfgod  797.750000              892.5000
#   5              702.0       lex_node  863.083333              894.9375
#   20             795.0         zacxbt  792.750000              802.5000
#   40             530.0         zacxbt  528.500000              535.0000
#   42               NaN  chumbawamba22  572.750000              551.0000
#
#       Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
#   0           991.875          1.135131       0.094000     0.09890        378.0
#   5           963.000          1.000000       0.099500     0.09999        282.0
#   20          829.125          1.016891       0.032300     0.04150        335.0
#   40          552.750          1.016891       0.007512     0.00880       1630.0
#   42          549.500          2.418870       0.025499     0.02550        271.0
#
#   [5 rows x 57 columns],
#             hero_name     hero_handle   hero_handle.1      hero_rarity_index  \
#   1              Iced       IcedKnife       IcedKnife            618539620_3
#   3    wallstreetbets  wallstreetbets  wallstreetbets            588569122_4
#   12  Hugo Martingale  HugoMartingale  HugoMartingale  1635676907529285642_3
#   51  kipit | fan/acc         0xKipit         0xKipit   720313843021385728_3
#   58     Tim Copeland    Timccopeland    Timccopeland   953233327238021120_4
#
#       cards_number  listed_cards_number  in_deck  gliding_score  card_in_deck  \
#   1              1                    0     True    1006.658424         False
#   3              1                    0     True     951.583435          True
#   12             1                    0     True     762.363567          True
#   51             1                    0     True     298.771874         False
#   58             4                    0     True     206.785536         False
#
#                                             picture_url  ...  Main 1  \
#   1   https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   853.5
#   3   https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN
#   12  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   592.5
#   51  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   645.0
#   58  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   282.0
#
#       Flash Tournament   hero_handle_y     Average  Main_Tournaments_Ave  \
#   1              903.0       IcedKnife  830.916667            894.375000
#   3                NaN  wallstreetbets  808.000000            907.857143
#   12             658.5  HugoMartingale  620.250000            809.062500
#   51             471.0         0xKipit  615.000000            574.875000
#   58             797.0    Timccopeland  408.333333            481.000000
#
#       Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
#   1           929.625          2.114827       0.145000     0.14650        127.0
#   3           931.000               NaN       0.221000     0.28000         67.0
#   12          834.000         77.281181       0.066000     0.07400        142.0
#   51          456.000          2.266849       0.028500     0.02898        283.0
#   58          408.750          6.253199       0.008511     0.01070       1219.0
#
#   [5 rows x 57 columns],
#          hero_name   hero_handle hero_handle.1      hero_rarity_index  \
#   2           Minh  MINHxDYNASTY  MINHxDYNASTY  1310378599984148480_3
#   13     K A L E O   CryptoKaleo   CryptoKaleo   906234475604037637_4
#   15       PreRich     0xprerich     0xprerich  1585936726370852865_3
#   57         apix🎮      apixtwts      apixtwts  1400381995558047749_3
#   58  Tim Copeland  Timccopeland  Timccopeland   953233327238021120_4
#
#       cards_number  listed_cards_number  in_deck  gliding_score  card_in_deck  \
#   2              1                    0     True     968.333497         False
#   13             2                    0    False     743.462476         False
#   15             1                    0     True     694.033718         False
#   57             1                    0    False     210.801498         False
#   58             4                    0     True     206.785536         False
#
#                                             picture_url  ...  Main 1  \
#   2   https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN
#   13  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN
#   15  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   853.5
#   57  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   927.0
#   58  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   282.0
#
#       Flash Tournament hero_handle_y     Average  Main_Tournaments_Ave  \
#   2                NaN  MINHxDYNASTY  692.250000              748.1250
#   13               NaN   CryptoKaleo  612.500000              610.2500
#   15             490.5     0xprerich  803.000000              791.0625
#   57             565.5      apixtwts  669.500000              630.0000
#   58             797.0  Timccopeland  408.333333              481.0000
#
#       Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
#   2           898.500         23.786385       0.088500     0.08500         66.0
#   13          844.500          1.016891       0.068000     0.06700        626.0
#   15          806.625          1.016891       0.055501     0.06968        161.0
#   57          430.500          1.540522       0.023510     0.02800        167.0
#   58          408.750          6.253199       0.008511     0.01070       1219.0
#
#   [5 rows x 57 columns],
#          hero_name     hero_handle   hero_handle.1      hero_rarity_index  \
#   4         kmoney       kmoney_69       kmoney_69  1404603419101306881_3
#   17      ciniz 👁️     screentimes     screentimes  1093242943127932930_4
#   21           W3Q       Web3Quant       Web3Quant  1518981537307496448_4
#   49          Adam  surfcoderepeat  surfcoderepeat            408488225_3
#   58  Tim Copeland    Timccopeland    Timccopeland   953233327238021120_4
#
#       cards_number  listed_cards_number  in_deck  gliding_score  card_in_deck  \
#   4              1                    0     True     870.128891         False
#   17             3                    1     True     663.021056         False
#   21             1                    0     True     607.452884         False
#   49             1                    0     True     320.248772         False
#   58             4                    0     True     206.785536         False
#
#                                             picture_url  ...  Main 1  \
#   4   https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN
#   17  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   741.0
#   21  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   956.0
#   49  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   894.0
#   58  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   282.0
#
#       Flash Tournament   hero_handle_y     Average  Main_Tournaments_Ave  \
#   4                NaN       kmoney_69  752.062500              851.2500
#   17             639.0     screentimes  591.000000              668.3750
#   21             877.0       Web3Quant  745.944444              689.0000
#   49             564.0  surfcoderepeat  622.750000              559.3125
#   58             797.0    Timccopeland  408.333333              481.0000
#
#       Main_Last_4_Ave  inflation_degree  lastSalePrice lowestPrice  rarityCount
#   4           776.250          3.803958       0.072500     0.09999         90.0
#   17          724.500          1.168913       0.027230     0.03000        349.0
#   21          779.500          1.202696       0.068137     0.08880         86.0
#   49          389.625          1.456066       0.027500     0.02780        179.0
#   58          408.750          6.253199       0.008511     0.01070       1219.0
#
#   [5 rows x 57 columns]]}

# %%
import pickle  # To save and load precomputed combinations

# Save precomputed combinations
with open('precomputed_combos_silver.pkl', 'wb') as f:
    pickle.dump(precomputed_combos_silver, f)

# Load precomputed combinations (instead of recomputing)
with open('precomputed_combos_silver.pkl', 'rb') as f:
    precomputed_combos_silver = pickle.load(f)

# %%
# Function to filter out already used cards
def filter_used_cards(combinations, used_cards):
    filtered_combos = []
    for combo_indices, scores in combinations:
        if not any(card in used_cards for card in combo_indices):
            filtered_combos.append((combo_indices, scores))
    return filtered_combos

# Load portfolio_scores
portfolio_scores = pd.read_csv('data/portfolio.csv')

# Track used cards from Silver decks
used_cards_silver = set()
for deck in best_decks_silver['Main_Last_4_Ave']:
    used_cards_silver.update(deck.index)

# Filter out combinations that use Silver cards for Bronze deck calculation
filtered_combos_bronze = filter_used_cards(precomputed_combos_silver, used_cards_silver)

# Ensure Bronze deck does not exceed star limit
def filter_by_star_limit(combinations, max_stars):
    valid_combinations = []
    for combo_indices, scores in combinations:
        total_stars = portfolio_scores.loc[list(combo_indices), 'hero_stars'].sum()
        if total_stars <= max_stars:
            valid_combinations.append((combo_indices, scores))
    return valid_combinations

# Apply star limit for Bronze
filtered_combos_bronze = filter_by_star_limit(filtered_combos_bronze, max_stars_bronze)

# Now proceed to generate Bronze decks using the filtered combinations
best_decks_bronze = find_best_decks(filtered_combos_bronze, portfolio_scores, max_decks_bronze, score_columns)

# Display the results for each deck in Bronze Tournament
for col in best_decks_bronze:
    for i, deck in enumerate(best_decks_bronze[col]):
        print(f"\nBest Combination DataFrame for {col}, Bronze Deck {i+1}:")
        print(deck)
        print(f"Total {col} score: {deck[col].sum()}")
# Out:
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 1:
#                hero_name     hero_handle      hero_rarity_index  cards_number  \
# 4   Wizard Of SoHo (🍷,🍷)    wizardofsoho  1175781003245191178_4             1
# 32                  Adam  surfcoderepeat            408488225_3             1
# 33       kipit | fan/acc         0xKipit   720313843021385728_3             1
# 62                 Herro     HerroCrypto   949016786506100736_4             4
# 63               foobar/        0xfoobar  1356386110847377408_3             2
#
#     listed_cards_number  in_deck  gliding_score  card_in_deck  \
# 4                     0    False     878.345553         False
# 32                    0     True     473.938113         False
# 33                    0     True     460.175090         False
# 62                    0    False     163.535235         False
# 63                    0    False     146.043560         False
#
#                                           picture_url  rarity  ...  \
# 4   https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 32  https://fantasy-top-cards.s3.eu-north-1.amazon...       3  ...
# 33  https://fantasy-top-cards.s3.eu-north-1.amazon...       3  ...
# 62  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 63  https://fantasy-top-cards.s3.eu-north-1.amazon...       3  ...
#
#     Common Only ✳️ Capped 20 🌟 Main 2  Main 1  Flash Tournament     Average  \
# 4                        679.0  700.0     NaN               NaN  728.071429
# 32                       784.5  634.5   894.0             564.0  669.375000
# 33                       561.0  714.0   645.0             471.0  651.562500
# 62                       723.0  643.0   709.0             407.0  487.875000
# 63                       873.0  549.0   337.5             360.0  709.218750
#
#     Main_Tournaments_Ave  Main_Last_4_Ave lastSalePrice  lowestPrice  \
# 4             761.285714          810.750       0.08980     0.115000
# 32            593.785714          480.750       0.02658     0.027289
# 33            594.214286          504.375       0.02890     0.028500
# 62            450.714286          406.500       0.00681     0.007300
# 63            644.357143          450.750       0.02306     0.026300
#
#     rarityCount
# 4           112
# 32          166
# 33          285
# 62         1759
# 63          417
#
# [5 rows x 50 columns]
# Total Main_Last_4_Ave score: 2653.125
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 2:
#       hero_name  hero_handle      hero_rarity_index  cards_number  \
# 30     ciniz 👁️  screentimes  1093242943127932930_4             2
# 34  Luca Netz 🐧     LucaNetz   807982663000674305_4             1
# 58        apix🎮     apixtwts  1400381995558047749_4             1
# 62        Herro  HerroCrypto   949016786506100736_4             4
# 63      foobar/     0xfoobar  1356386110847377408_3             2
#
#     listed_cards_number  in_deck  gliding_score  card_in_deck  \
# 30                    0    False     474.422217         False
# 34                    0    False     459.873562         False
# 58                    0    False     231.025305         False
# 62                    0    False     163.535235         False
# 63                    0    False     146.043560         False
#
#                                           picture_url  rarity  ...  \
# 30  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 34  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 58  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 62  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 63  https://fantasy-top-cards.s3.eu-north-1.amazon...       3  ...
#
#     Common Only ✳️ Capped 20 🌟 Main 2  Main 1  Flash Tournament     Average  \
# 30                       557.0  618.0   741.0             639.0  613.500000
# 34                       197.0  367.0     NaN               NaN  480.642857
# 58                       463.0  422.0   618.0             377.0  485.312500
# 62                       723.0  643.0   709.0             407.0  487.875000
# 63                       873.0  549.0   337.5             360.0  709.218750
#
#     Main_Tournaments_Ave  Main_Last_4_Ave lastSalePrice  lowestPrice  \
# 30            651.571429           691.25       0.03899      0.03640
# 34            518.428571           610.50       0.01234      0.01500
# 58            462.428571           391.25       0.00649      0.00652
# 62            450.714286           406.50       0.00681      0.00730
# 63            644.357143           450.75       0.02306      0.02630
#
#     rarityCount
# 30          346
# 34          459
# 58          948
# 62         1759
# 63          417
#
# [5 rows x 50 columns]
# Total Main_Last_4_Ave score: 2550.25
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 3:
#     hero_name      hero_handle      hero_rarity_index  cards_number  \
# 22   Franklin  franklinisbored  1323747353308835840_4             1
# 30   ciniz 👁️      screentimes  1093242943127932930_4             2
# 39     Cirrus        CirrusNFT   834123445856145408_4             1
# 57  KJ Crypto  koreanjewcrypto   873190778910253056_4             2
# 62      Herro      HerroCrypto   949016786506100736_4             4
#
#     listed_cards_number  in_deck  gliding_score  card_in_deck  \
# 22                    0    False     578.588094         False
# 30                    0    False     474.422217         False
# 39                    0    False     429.216087         False
# 57                    0    False     239.776101         False
# 62                    0    False     163.535235         False
#
#                                           picture_url  rarity  ...  \
# 22  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 30  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 39  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 57  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 62  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
#
#     Common Only ✳️ Capped 20 🌟 Main 2  Main 1  Flash Tournament     Average  \
# 22                       664.0  647.0     NaN               NaN  622.428571
# 30                       557.0  618.0   741.0             639.0  613.500000
# 39                       767.0  692.0   746.0             712.0  572.187500
# 57                       695.0  584.0   621.0             432.0  483.625000
# 62                       723.0  643.0   709.0             407.0  487.875000
#
#     Main_Tournaments_Ave  Main_Last_4_Ave lastSalePrice  lowestPrice  \
# 22            621.285714           604.00      0.025469      0.02615
# 30            651.571429           691.25      0.038990      0.03640
# 39            456.000000           447.00      0.027870      0.02720
# 57            325.571429           377.50      0.010000      0.00900
# 62            450.714286           406.50      0.006810      0.00730
#
#     rarityCount
# 22          411
# 30          346
# 39          867
# 57         1377
# 62         1759
#
# [5 rows x 50 columns]
# Total Main_Last_4_Ave score: 2526.25
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 4:
#     hero_name      hero_handle      hero_rarity_index  cards_number  \
# 21         qw           QwQiao   712457848874086400_4             1
# 27         me   mememe69696969  1453982860663087107_4             2
# 38       cozy   cozymaximalist  1475612593830178820_4             1
# 57  KJ Crypto  koreanjewcrypto   873190778910253056_4             2
# 62      Herro      HerroCrypto   949016786506100736_4             4
#
#     listed_cards_number  in_deck  gliding_score  card_in_deck  \
# 21                    0    False     621.505066         False
# 27                    0    False     513.692834         False
# 38                    0    False     433.336163         False
# 57                    0    False     239.776101         False
# 62                    0    False     163.535235         False
#
#                                           picture_url  rarity  ...  \
# 21  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 27  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 38  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 57  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 62  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
#
#     Common Only ✳️ Capped 20 🌟 Main 2  Main 1  Flash Tournament   Average  \
# 21                       559.0  666.0   666.0             328.0  506.6875
# 27                       659.0  660.0   776.0             315.0  599.8125
# 38                       312.0  204.0   616.0             719.0  506.7500
# 57                       695.0  584.0   621.0             432.0  483.6250
# 62                       723.0  643.0   709.0             407.0  487.8750
#
#     Main_Tournaments_Ave  Main_Last_4_Ave lastSalePrice  lowestPrice  \
# 21            522.000000           598.75      0.017566      0.01780
# 27            549.428571           561.00      0.013980      0.01299
# 38            520.571429           489.50      0.012000      0.01249
# 57            325.571429           377.50      0.010000      0.00900
# 62            450.714286           406.50      0.006810      0.00730
#
#     rarityCount
# 21          609
# 27         2143
# 38          505
# 57         1377
# 62         1759
#
# [5 rows x 50 columns]
# Total Main_Last_4_Ave score: 2433.25
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 5:
#                        hero_name     hero_handle      hero_rarity_index  \
# 7                    Taiki Maeda     TaikiMaeda2  1064421325186359296_4
# 27                            me  mememe69696969  1453982860663087107_4
# 28                   Chumbawamba   chumbawamba22  1479247421330837508_4
# 46  𝔅ℜ𝔊 lil clearpill (cute/acc)    lilclearpill  1396144613233238018_4
# 53                       Ben Roy        benroy__  1170153611499720704_4
#
#     cards_number  listed_cards_number  in_deck  gliding_score  card_in_deck  \
# 7              2                    0     True     783.014592         False
# 27             2                    0    False     513.692834         False
# 28             1                    0    False     490.377627          True
# 46             1                    0    False     381.808459         False
# 53             1                    0    False     323.906771         False
#
#                                           picture_url  rarity  ...  \
# 7   https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 27  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 28  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 46  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 53  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
#
#     Common Only ✳️ Capped 20 🌟 Main 2  Main 1  Flash Tournament   Average  \
# 7                        353.0  251.0   505.0             474.0  365.1250
# 27                       659.0  660.0   776.0             315.0  599.8125
# 28                       682.0  751.0     NaN               NaN  620.5000
# 46                       646.0  662.0   711.0             258.0  423.8125
# 53                       772.0  655.0   583.0             345.0  524.3750
#
#     Main_Tournaments_Ave  Main_Last_4_Ave lastSalePrice  lowestPrice  \
# 7             363.857143           368.75      0.025299     0.021999
# 27            549.428571           561.00      0.013980     0.012990
# 28            571.857143           559.00      0.016390     0.017700
# 46            357.571429           394.75      0.006000     0.006200
# 53            470.142857           393.75      0.007687     0.007999
#
#     rarityCount
# 7           974
# 27         2143
# 28          225
# 46         1332
# 53         1873
#
# [5 rows x 50 columns]
# Total Main_Last_4_Ave score: 2277.25
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 6:
#           hero_name     hero_handle      hero_rarity_index  cards_number  \
# 7       Taiki Maeda     TaikiMaeda2  1064421325186359296_4             2
# 23          Mercury   TraderMercury  1180256836416614401_4             1
# 40              MAX    max_the_plug  1526588836536586240_4             1
# 42  Hugo Martingale  HugoMartingale  1635676907529285642_4             1
# 65       Teng Yan 🥕     0xPrismatic  1299523632868110338_4             3
#
#     listed_cards_number  in_deck  gliding_score  card_in_deck  \
# 7                     0     True     783.014592         False
# 23                    0    False     572.809596          True
# 40                    0    False     426.552009         False
# 42                    0    False     415.194313         False
# 65                    0    False      46.657762         False
#
#                                           picture_url  rarity  ...  \
# 7   https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 23  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 40  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 42  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 65  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
#
#     Common Only ✳️ Capped 20 🌟 Main 2  Main 1  Flash Tournament     Average  \
# 7                        353.0  251.0   505.0             474.0  365.125000
# 23                         NaN    NaN     NaN               NaN  567.571429
# 40                       728.0  635.0   568.0             406.0  509.625000
# 42                       159.0  138.0   395.0             439.0  420.937500
# 65                       427.0  466.0   478.0             509.0  431.875000
#
#     Main_Tournaments_Ave  Main_Last_4_Ave lastSalePrice  lowestPrice  \
# 7             363.857143           368.75      0.025299     0.021999
# 23            564.000000           557.50      0.017000     0.020100
# 40            469.857143           448.50      0.005671     0.006919
# 42            525.285714           533.75      0.011702     0.013000
# 65            350.285714           260.50      0.005500     0.006500
#
#     rarityCount
# 7           974
# 23          196
# 40          663
# 42          907
# 65         1863
#
# [5 rows x 50 columns]
# Total Main_Last_4_Ave score: 2169.0
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 7:
#           hero_name   hero_handle      hero_rarity_index  cards_number  \
# 13             Minh  MINHxDYNASTY  1310378599984148480_4             5
# 15  _gabrielShapir0      lex_node   954015928924057601_4             1
# 60           mikado      0xMikado  1354867416430501890_4             4
# 65       Teng Yan 🥕   0xPrismatic  1299523632868110338_4             3
# 66           CBB0FE        Cbb0fe  1703332734603591680_4             1
#
#     listed_cards_number  in_deck  gliding_score  card_in_deck  \
# 13                    0    False     685.868761         False
# 15                    0    False     654.019173         False
# 60                    0    False     204.528023         False
# 65                    0    False      46.657762         False
# 66                    0    False       0.000000          True
#
#                                           picture_url  rarity  ...  \
# 13  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 15  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 60  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 65  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 66  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
#
#     Common Only ✳️ Capped 20 🌟 Main 2  Main 1  Flash Tournament     Average  \
# 13                       504.0  298.0     NaN               NaN  477.785714
# 15                       699.0  409.0   579.0             468.0  608.125000
# 60                       440.0  485.0   601.0             424.0  463.000000
# 65                       427.0  466.0   478.0             509.0  431.875000
# 66                       644.0  279.0   616.0             815.0  495.250000
#
#     Main_Tournaments_Ave  Main_Last_4_Ave lastSalePrice  lowestPrice  \
# 13            479.428571           533.25       0.01380     0.016500
# 15            597.857143           630.75       0.01920     0.022699
# 60            380.571429           239.00       0.00777     0.007490
# 65            350.285714           260.50       0.00550     0.006500
# 66            393.000000           343.25       0.01600     0.015000
#
#     rarityCount
# 13          623
# 15         1385
# 60         2169
# 65         1863
# 66          822
#
# [5 rows x 50 columns]
# Total Main_Last_4_Ave score: 2006.75
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 8:
#                                 hero_name   hero_handle  \
# 13                                   Minh  MINHxDYNASTY
# 16  🐧 Ethereum Damien (Memecoin Maxi) 🧢🦈🐱      0xDamien
# 55                        kipit | fan/acc       0xKipit
# 60                                 mikado      0xMikado
# 65                             Teng Yan 🥕   0xPrismatic
#
#         hero_rarity_index  cards_number  listed_cards_number  in_deck  \
# 13  1310378599984148480_4             5                    0    False
# 16            837985489_4             1                    0    False
# 55   720313843021385728_4             3                    0    False
# 60  1354867416430501890_4             4                    0    False
# 65  1299523632868110338_4             3                    0    False
#
#     gliding_score  card_in_deck  \
# 13     685.868761         False
# 16     636.359931         False
# 55     306.783393         False
# 60     204.528023         False
# 65      46.657762         False
#
#                                           picture_url  rarity  ...  \
# 13  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 16  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 55  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 60  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 65  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
#
#     Common Only ✳️ Capped 20 🌟 Main 2  Main 1  Flash Tournament     Average  \
# 13                       504.0  298.0     NaN               NaN  477.785714
# 16                       701.0  657.0     NaN               NaN  599.857143
# 55                       374.0  476.0   430.0             314.0  434.375000
# 60                       440.0  485.0   601.0             424.0  463.000000
# 65                       427.0  466.0   478.0             509.0  431.875000
#
#     Main_Tournaments_Ave  Main_Last_4_Ave lastSalePrice  lowestPrice  \
# 13            479.428571           533.25       0.01380      0.01650
# 16            578.428571           596.50       0.01790      0.02040
# 55            396.142857           336.25       0.00550      0.00589
# 60            380.571429           239.00       0.00777      0.00749
# 65            350.285714           260.50       0.00550      0.00650
#
#     rarityCount
# 13          623
# 16          289
# 55         2214
# 60         2169
# 65         1863
#
# [5 rows x 50 columns]
# Total Main_Last_4_Ave score: 1965.5
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 9:
#           hero_name     hero_handle      hero_rarity_index  cards_number  \
# 13             Minh    MINHxDYNASTY  1310378599984148480_4             5
# 31           kmoney       kmoney_69  1404603419101306881_4             2
# 54             Adam  surfcoderepeat            408488225_4             3
# 55  kipit | fan/acc         0xKipit   720313843021385728_4             3
# 60           mikado        0xMikado  1354867416430501890_4             4
#
#     listed_cards_number  in_deck  gliding_score  card_in_deck  \
# 13                    0    False     685.868761         False
# 31                    0    False     474.172495         False
# 54                    0    False     315.958742         False
# 55                    0    False     306.783393         False
# 60                    0    False     204.528023         False
#
#                                           picture_url  rarity  ...  \
# 13  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 31  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 54  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 55  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 60  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
#
#     Common Only ✳️ Capped 20 🌟 Main 2  Main 1  Flash Tournament     Average  \
# 13                       504.0  298.0     NaN               NaN  477.785714
# 31                       435.0  117.0     NaN               NaN  523.714286
# 54                       523.0  423.0   596.0             376.0  446.250000
# 55                       374.0  476.0   430.0             314.0  434.375000
# 60                       440.0  485.0   601.0             424.0  463.000000
#
#     Main_Tournaments_Ave  Main_Last_4_Ave lastSalePrice  lowestPrice  \
# 13            479.428571           533.25      0.013800      0.01650
# 31            560.571429           506.50      0.022300      0.02078
# 54            395.857143           320.50      0.005322      0.00655
# 55            396.142857           336.25      0.005500      0.00589
# 60            380.571429           239.00      0.007770      0.00749
#
#     rarityCount
# 13          623
# 31          448
# 54         1615
# 55         2214
# 60         2169
#
# [5 rows x 50 columns]
# Total Main_Last_4_Ave score: 1935.5
#
# Best Combination DataFrame for Main_Last_4_Ave, Bronze Deck 10:
#           hero_name     hero_handle      hero_rarity_index  cards_number  \
# 13             Minh    MINHxDYNASTY  1310378599984148480_4             5
# 31           kmoney       kmoney_69  1404603419101306881_4             2
# 54             Adam  surfcoderepeat            408488225_4             3
# 55  kipit | fan/acc         0xKipit   720313843021385728_4             3
# 60           mikado        0xMikado  1354867416430501890_4             4
#
#     listed_cards_number  in_deck  gliding_score  card_in_deck  \
# 13                    0    False     685.868761         False
# 31                    0    False     474.172495         False
# 54                    0    False     315.958742         False
# 55                    0    False     306.783393         False
# 60                    0    False     204.528023         False
#
#                                           picture_url  rarity  ...  \
# 13  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 31  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 54  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 55  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
# 60  https://fantasy-top-cards.s3.eu-north-1.amazon...       4  ...
#
#     Common Only ✳️ Capped 20 🌟 Main 2  Main 1  Flash Tournament     Average  \
# 13                       504.0  298.0     NaN               NaN  477.785714
# 31                       435.0  117.0     NaN               NaN  523.714286
# 54                       523.0  423.0   596.0             376.0  446.250000
# 55                       374.0  476.0   430.0             314.0  434.375000
# 60                       440.0  485.0   601.0             424.0  463.000000
#
#     Main_Tournaments_Ave  Main_Last_4_Ave lastSalePrice  lowestPrice  \
# 13            479.428571           533.25      0.013800      0.01650
# 31            560.571429           506.50      0.022300      0.02078
# 54            395.857143           320.50      0.005322      0.00655
# 55            396.142857           336.25      0.005500      0.00589
# 60            380.571429           239.00      0.007770      0.00749
#
#     rarityCount
# 13          623
# 31          448
# 54         1615
# 55         2214
# 60         2169
#
# [5 rows x 50 columns]
# Total Main_Last_4_Ave score: 1935.5

# %% [markdown]
# ### Work Out Best Bronze

# %%
print("Step 1: Filter rows where hero_rarity_index ends in '4'")

# Filter rows where hero_rarity_index ends in '4'
filtered_df = portfolio_scores[portfolio_scores['hero_rarity_index'].astype(str).str.endswith('4')]

print(f"Filtered DataFrame has {len(filtered_df)} rows")

print("Step 2: Generate all combinations of 5 cards")
# Generate all combinations of 5 cards
combinations = list(itertools.combinations(filtered_df.index, 5))

print(f"Generated {len(combinations)} combinations")

# Define the columns for which we want to find the optimum combination
score_columns = ['hero_fantasy_score', 'Main 8', 'Main 7', 'Average', 'Main_Tournaments_Ave']

# Initialize variables to store the best combination and its scores
best_combination = {col: None for col in score_columns}
best_scores = {col: float('-inf') for col in score_columns}

print("Step 3: Evaluate each combination")
# Evaluate each combination with a progress bar
for combo in tqdm(combinations, desc="Evaluating combinations"):
    combo_df = filtered_df.loc[list(combo)]
    total_stars = combo_df['hero_stars'].sum()
    
    # Check if the combination meets the hero_stars constraint
    if total_stars <= 18:
        for col in score_columns:
            score = combo_df[col].sum()
            
            if score > best_scores[col]:
                best_scores[col] = score
                best_combination[col] = combo_df

print("Step 4: Print the best combinations and their scores")
# Print the best combinations and their scores
for col in score_columns:
    print(f"Best combination for {col}:")
    print(best_combination[col])
    print(f"Total {col} score: {best_scores[col]}\n")
# Out:
# Step 1: Filter rows where hero_rarity_index ends in '4'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 print("Step 1: Filter rows where hero_rarity_index ends in '4'")
#       3 # Filter rows where hero_rarity_index ends in '4'
# ----> 4 filtered_df = portfolio_scores[portfolio_scores['hero_rarity_index'].astype(str).str.endswith('4')]
#       6 print(f"Filtered DataFrame has {len(filtered_df)} rows")
#       8 print("Step 2: Generate all combinations of 5 cards")
#
# NameError: name 'portfolio_scores' is not defined

# %%
best_combination['Average'].to_csv('bronze_best_Average.csv', index=False)

# %% [markdown]
# ### Work out best silver from own cards

# %%
import pandas as pd
from itertools import combinations
from tqdm import tqdm

# Function to find the best combination of cards
def find_best_combinations(df, max_stars, max_rarity_3_cards):
    score_columns = ['Average', 'Main_Tournaments_Ave']
    
    # Debug: Print the columns of the DataFrame
    print("Columns in DataFrame:", df.columns.tolist())
    
    for col in score_columns:
        if col not in df.columns:
            raise KeyError(f"Column '{col}' not found in DataFrame")
    
    best_combinations = {col: None for col in score_columns}
    best_scores = {col: 0 for col in score_columns}
    
    # Use tqdm to track progress
    print("Starting combination search...")
    for combination in tqdm(combinations(df.index, 5), total=len(list(combinations(df.index, 5)))):
        combination_df = df.loc[list(combination)]
        
        total_stars = combination_df['hero_stars'].sum()
        rarity_3_count = combination_df['hero_rarity_index'].apply(lambda x: str(x).endswith('3')).sum()
        
        # Check if the combination meets the constraints
        if total_stars <= max_stars and rarity_3_count <= max_rarity_3_cards:
            for col in score_columns:
                current_score = combination_df[col].sum()
                
                # Update the best combination for each score column if the current one is better
                if current_score > best_scores[col]:
                    best_combinations[col] = combination_df
                    best_scores[col] = current_score

    return best_combinations, best_scores

# Parameters
max_stars = 22
max_rarity_3_cards = 3

# Finding the best combinations
best_combinations, best_scores = find_best_combinations(portfolio_scores, max_stars, max_rarity_3_cards)

for col in best_combinations:
    print(f"\nBest Combination DataFrame for {col}:")
    print(best_combinations[col])
    print(f"Best Score for {col}: {best_scores[col]}")
# Out:
# Columns in DataFrame: ['owner', 'hero_rarity_index', 'cards_number', 'listed_cards_number', 'in_deck', 'card_id', 'card_owner', 'gliding_score', 'card_in_deck', 'picture_url', 'token_id', 'rarity', 'hero_id', 'hero_name', 'hero_handle', 'hero_profile_image_url', 'hero_followers_count', 'hero_stars', 'hero_fantasy_score', 'hero_views', 'hero_current_rank', 'hero_trades', 'Main 8', 'Main 7', 'Main 6', 'Main 5', 'All Rarities 22 days', 'Main 4', 'Main 3', 'Common Only Capped 15', 'Rare Only', 'Common Only ?? Capped 20 ??', 'Main 2', 'Main 1', 'Flash Tournament', 'Average', 'Main_Tournaments_Ave']
# Starting combination search...
# 100%|█████████████████████████████████████████████████████████████████████| 6471002/6471002 [2:40:01<00:00, 673.97it/s]
# Best Combination DataFrame for Average:
#                                          owner      hero_rarity_index  \
# 4   0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a            588569122_4
# 8   0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a   886765719391789057_3
# 9   0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a   954015928924057601_3
# 38  0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a           2593497397_4
# 49  0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a  1356386110847377408_3
#
#     cards_number  listed_cards_number  in_deck  \
# 4              1                    0     True
# 8              1                    0     True
# 9              1                    0     True
# 38             1                    0     True
# 49             2                    0     True
#
#                                               card_id  \
# 4   475494_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 8   280224_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 9   408340_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 38  475325_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 49  359854_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
#
#                                     card_owner  gliding_score  card_in_deck  \
# 4   0xBEAf5102bB665d9D87EFC5346379518E539789d1     898.069286          True
# 8   0x0000000000000000000000000000000000000000     800.095347         False
# 9   0xA1023983e2309b722488EDcEdfae8556c1d46a98     798.326693         False
# 38  0xf8705D733733B0f35206Fdd38aBb33f845bA0008     406.580661          True
# 49  0x09dc6f15aE2825310F801CE172De2D6a8eE4Ac2e     344.844119         False
#
#                                           picture_url  ...  Main 4  Main 3  \
# 4   https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN     NaN
# 8   https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   636.0  1056.0
# 9   https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   832.5   963.0
# 38  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   764.0   506.0
# 49  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   973.5   901.5
#
#     Common Only Capped 15 Rare Only Common Only ?? Capped 20 ?? Main 2  \
# 4                     NaN       NaN                         NaN    NaN
# 8                   661.5     867.0                      1042.5  813.0
# 9                  1153.5    1066.5                      1048.5  613.5
# 38                  743.0     867.0                       837.0  646.0
# 49                  994.5    1057.5                       873.0  549.0
#
#     Main 1  Flash Tournament     Average  Main_Tournaments_Ave
# 4      NaN               NaN  890.500000                882.00
# 8   1152.0             795.0  806.423077                699.00
# 9    868.5             702.0  912.807692                887.25
# 38     NaN               NaN  607.363636                521.50
# 49   337.5             360.0  783.692308                837.75
#
# [5 rows x 37 columns]
# Best Score for Average: 4000.7867132867136
#
# Best Combination DataFrame for Main_Tournaments_Ave:
#                                          owner      hero_rarity_index  \
# 2   0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a  1404603419101306881_3
# 4   0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a            588569122_4
# 9   0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a   954015928924057601_3
# 49  0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a  1356386110847377408_3
# 60  0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a  1356386110847377408_4
#
#     cards_number  listed_cards_number  in_deck  \
# 2              1                    0    False
# 4              1                    0     True
# 9              1                    0     True
# 49             2                    0     True
# 60             2                    0     True
#
#                                               card_id  \
# 2   433270_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 4   475494_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 9   408340_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 49  359854_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 60       2_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
#
#                                     card_owner  gliding_score  card_in_deck  \
# 2   0xd3d69f8168Ea7527AdD1e55Bb27EBde616F05758     910.172208          True
# 4   0xBEAf5102bB665d9D87EFC5346379518E539789d1     898.069286          True
# 9   0xA1023983e2309b722488EDcEdfae8556c1d46a98     798.326693         False
# 49  0x09dc6f15aE2825310F801CE172De2D6a8eE4Ac2e     344.844119         False
# 60  0xFfBaDD7F53a5A0b621aF5d42DBC2E09Bf1E22E94     229.896079          True
#
#                                           picture_url  ...  Main 4  Main 3  \
# 2   https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   964.5   834.0
# 4   https://fantasy-top-cards.s3.eu-north-1.amazon...  ...     NaN     NaN
# 9   https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   832.5   963.0
# 49  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   973.5   901.5
# 60  https://fantasy-top-cards.s3.eu-north-1.amazon...  ...   649.0   601.0
#
#     Common Only Capped 15 Rare Only Common Only ?? Capped 20 ?? Main 2  \
# 2                   982.5     816.0                       652.5  175.5
# 4                     NaN       NaN                         NaN    NaN
# 9                  1153.5    1066.5                      1048.5  613.5
# 49                  994.5    1057.5                       873.0  549.0
# 60                  663.0     705.0                       582.0  366.0
#
#     Main 1  Flash Tournament     Average  Main_Tournaments_Ave
# 2      NaN               NaN  807.681818               943.125
# 4      NaN               NaN  890.500000               882.000
# 9    868.5             702.0  912.807692               887.250
# 49   337.5             360.0  783.692308               837.750
# 60   225.0             240.0  522.461538               558.500
#
# [5 rows x 37 columns]
# Best Score for Main_Tournaments_Ave: 4108.625

# %%
best_combinations['Main_Tournaments_Ave'].to_csv('silver_best_Main_Tournaments_Ave.csv', index=False)

# %% [markdown]
# ## Merge Upcoming Entries with Scores

# %%
# Combine the Bronze and Silver DataFrames
upcoming_Bronze = dataframes['upcoming_Bronze']
upcoming_Silver = dataframes['upcoming_Silver']

# Add a column to indicate the source
upcoming_Bronze['tournament_type'] = 'Bronze'
upcoming_Silver['tournament_type'] = 'Silver'

# Combine the DataFrames
combined_df = pd.concat([upcoming_Bronze, upcoming_Silver], ignore_index=True)

# Merge the combined DataFrame with tournament_scores DataFrame
tournament_scores_df = dataframes['tournament_scores']
merged_df = combined_df.merge(tournament_scores_df, left_on='hero_handle', right_on='Handle', how='left')

# Drop the 'Name' and 'Handle' columns from the merged DataFrame
merged_df = merged_df.drop(['Name', 'Handle'], axis=1)

merged_df.columns
# Out:
# Index(['entry_id', 'card_id', 'card_owner', 'gliding_score', 'card_in_deck',
#        'picture_url', 'token_id', 'hero_rarity_index', 'hero_id', 'hero_name',
#        'hero_handle', 'hero_profile_image_url', 'hero_followers_count',
#        'hero_stars', 'hero_fantasy_score', 'hero_current_rank',
#        'tournament_fantasy_score', 'tournament_current_rank',
#        'tournament_views', 'tournament_type', 'Main 8', 'Main 7', 'Main 6',
#        'Main 5', 'All Rarities 22 days', 'Main 4', 'Main 3',
#        'Common Only Capped 15', 'Rare Only', 'Common Only ?? Capped 20 ??',
#        'Main 2', 'Main 1', 'Flash Tournament', 'Average',
#        'Main_Tournaments_Ave'],
#       dtype='object')

# %%
# Add the entry_name column
merged_df['entry_name'] = merged_df['tournament_type'] + ' ' + merged_df['entry_id'].astype(str)

# List of columns to be adjusted
score_columns = ['hero_fantasy_score', 'Main 8', 'Main 7', 'Main 6', 'Main 5', 
                 'All Rarities 22 days', 'Main 4', 'Main 3', 'Common Only Capped 15', 
                 'Rare Only', 'Common Only ?? Capped 20 ??', 'Main 2', 'Main 1', 
                 'Flash Tournament', 'Average', 'Main_Tournaments_Ave']

# Convert all score columns to numeric, coercing errors to NaNs
for col in score_columns:
    merged_df[col] = pd.to_numeric(merged_df[col], errors='coerce')

# Apply the multiplier before grouping
for col in score_columns:
    merged_df[col] = merged_df.apply(lambda row: row[col] * 1.5 if row['hero_rarity_index'].endswith('3') and row['tournament_type'] == 'Silver' else row[col], axis=1)

# Function to sum columns while respecting NaNs
def sum_with_nan_check(group):
    result = {}
    for col in score_columns:
        if group[col].isnull().any():
            result[col] = float('nan')
        else:
            result[col] = group[col].sum()
    return pd.Series(result)

# Group by 'entry_name' and apply the sum_with_nan_check function
grouped_df = merged_df.groupby('entry_name').apply(sum_with_nan_check).reset_index()
# Out:
# C:\Users\beuzi\AppData\Local\Temp\ipykernel_17276\2514957361.py:29: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_df = merged_df.groupby('entry_name').apply(sum_with_nan_check).reset_index()

# %%
grouped_df
# Out:
#    entry_name  hero_fantasy_score  Main 8  Main 7  Main 6  Main 5  \
# 0    Bronze 1         2194.320617  2585.0  2505.0  3768.0  3132.0
# 1   Bronze 10         1979.917087  2184.0  2343.0  2679.0  2411.0
# 2    Bronze 2         2078.571725  1867.0  2745.0  2371.0  2411.0
# 3    Bronze 3         1911.823184  1875.0  2242.0  1775.0  2088.0
# 4    Bronze 4         1648.232070  1820.0  2241.0  2780.0  2526.0
# 5    Bronze 5         1923.814305  1967.0  1988.0  1688.0  1698.0
# 6    Bronze 6         2296.763519  2057.0  1844.0  2348.0  2662.0
# 7    Bronze 7         1831.271398  2081.0  2060.0  2785.0  2665.0
# 8    Bronze 8         2176.451479  2574.0  1700.0  2278.0  1677.0
# 9    Bronze 9         1676.719610  1405.0  1596.0  2245.0  2682.0
# 10   Silver 1         3540.209404  3856.0  1704.0  2394.0  2370.5
# 11   Silver 2         3165.407793  3263.5  3325.5  4479.0  4075.5
# 12   Silver 3         3285.731325  3338.0  3354.5  4044.0  3816.0
# 13   Silver 4         2814.508238  3218.5  3106.5  3458.0  3741.0
# 14   Silver 5         3249.568920  3267.5  4156.0  4903.5  4101.0
#
#     All Rarities 22 days  Main 4  Main 3  Common Only Capped 15  Rare Only  \
# 0                    NaN     NaN     NaN                    NaN        NaN
# 1                 2488.0  2565.0  2712.0                 2478.0     2544.0
# 2                    NaN     NaN     NaN                    NaN        NaN
# 3                    NaN     NaN     NaN                    NaN        NaN
# 4                 2191.0  2529.0  1988.0                 2696.0     2020.0
# 5                    NaN     NaN     NaN                    NaN        NaN
# 6                    NaN     NaN     NaN                    NaN        NaN
# 7                 2619.0  2586.0  2744.0                 3080.0     2175.0
# 8                 2393.0  2086.0  2271.0                 2489.0     2372.0
# 9                 2237.0  2298.0  2600.0                 2332.0     2456.0
# 10                3551.5  2728.5  3256.5                 4316.0     4552.0
# 11                3772.0  3701.0  3126.5                 3448.5     2925.5
# 12                3182.5  3352.5  3283.5                 3480.5     3783.5
# 13                3572.5  3552.0  3774.5                 4259.5     3410.0
# 14                   NaN     NaN     NaN                    NaN        NaN
#
#     Common Only ?? Capped 20 ??  Main 2  Main 1  Flash Tournament  \
# 0                           NaN     NaN     NaN               NaN
# 1                        2703.0  2471.0     NaN               NaN
# 2                           NaN     NaN     NaN               NaN
# 3                           NaN     NaN     NaN               NaN
# 4                        2425.0  2340.0     NaN               NaN
# 5                           NaN     NaN     NaN               NaN
# 6                           NaN     NaN     NaN               NaN
# 7                        2022.0  1701.0     NaN               NaN
# 8                        2713.0  2524.0     NaN               NaN
# 9                        2057.0  1956.0  2665.0            2210.0
# 10                       4402.0  4053.5     NaN               NaN
# 11                       2455.5  1964.5  2855.5            2560.5
# 12                       3519.0  2573.0     NaN               NaN
# 13                       3102.5  2148.0     NaN               NaN
# 14                          NaN     NaN     NaN               NaN
#
#         Average  Main_Tournaments_Ave
# 0   2705.125399           2684.416667
# 1   2449.200181           2375.750000
# 2   2323.932862           2340.166667
# 3   2077.836674           2123.833333
# 4   2255.877893           2279.000000
# 5   2049.024850           1900.250000
# 6   2739.781806           2378.333333
# 7   2387.252156           2348.000000
# 8   2315.866229           2009.250000
# 9   2195.371966           1995.250000
# 10  3380.995891           2664.750000
# 11  3253.054017           3591.375000
# 12  3464.296183           3465.250000
# 13  3331.160425           3404.500000
# 14  3690.245342           3720.250000

# %%
grouped_df[grouped_df[

# %%
# # Filter the DataFrame for rows where tournament_type is 'Silver'
# filtered_df = merged_df[merged_df['tournament_type'] == 'Silver']

# # Select only the 'hero_id' and 'hero_fantasy_score' columns
# result_df = filtered_df[['hero_name', 'hero_fantasy_score']]

# # Display the resulting DataFrame
# print(result_df)
# Out:
#                 hero_name  hero_fantasy_score
# 50                PreRich         1010.202513
# 51        _gabrielShapir0          837.883175
# 52  Pacman | Blur + Blast          573.357884
# 53              K A L E O          731.187600
# 54              KJ Crypto          387.578233
# 55                   Iced          795.019341
# 56        Hugo Martingale          788.938727
# 57                foobar/          316.421788
# 58               ciniz 👁️          599.511482
# 59                 Yano 🟪          665.516454
# 60           yieldfarming          903.579790
# 61        zac.eth 🧙🏻‍♂️♦️          781.841804
# 62                  apix🎮          669.451981
# 63                   Minh          372.268968
# 64        _gabrielShapir0          558.588783
# 65                 kmoney          898.002957
# 66                     qw          625.521905
# 67                foobar/          316.421788
# 68                   Iced          530.012894
# 69               AiRev //          444.548694
# 70           yieldfarming          903.579790
# 71                 mikado          301.764403
# 72         wallstreetbets          898.674415
# 73        kipit | fan/acc          459.981355
# 74                DCF GOD          685.568958

# %%
dataframes['upcoming_Silver']
# Out:
#     entry_id                                            card_id  \
# 0          1  254484_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 1          1  429727_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 2          1  144702_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 3          1  495229_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 4          1  272792_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 5          2  197263_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 6          2  262872_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 7          2  434003_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 8          2  191364_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 9          2  436924_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 10         3  475603_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 11         3  387335_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 12         3  319668_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 13         3  436850_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 14         3  341173_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 15         4  375498_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 16         4  495199_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 17         4  434452_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 18         4   34063_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 19         4  390290_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 20         5  486067_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 21         5   85472_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 22         5  495695_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 23         5  486109_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
# 24         5  460932_0x0AAADCf421A3143E5cB2dDB8452c03ae595B0734
#
#                                     card_owner  gliding_score  card_in_deck  \
# 0   0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a    1010.202513          True
# 1   0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     837.883175          True
# 2   0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     573.357884          True
# 3   0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     731.187600          True
# 4   0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     387.578233          True
# 5   0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     795.019341          True
# 6   0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     788.938727          True
# 7   0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     316.421788          True
# 8   0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     599.511482          True
# 9   0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     665.516454          True
# 10  0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     903.579790          True
# 11  0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     781.841804          True
# 12  0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     669.451981          True
# 13  0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     372.268968          True
# 14  0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     558.588783          True
# 15  0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     898.002957          True
# 16  0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     625.521905          True
# 17  0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     316.421788          True
# 18  0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     530.012894          True
# 19  0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     444.548694          True
# 20  0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     903.579790          True
# 21  0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     301.764403          True
# 22  0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     898.674415          True
# 23  0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     459.981355          True
# 24  0xDC0c171F4DB2790e565295c5287bCa9D4071EA1a     685.568958          True
#
#                                           picture_url  token_id  \
# 0   https://fantasy-top-cards.s3.eu-north-1.amazon...    254484
# 1   https://fantasy-top-cards.s3.eu-north-1.amazon...    429727
# 2   https://fantasy-top-cards.s3.eu-north-1.amazon...    144702
# 3   https://fantasy-top-cards.s3.eu-north-1.amazon...    495229
# 4   https://fantasy-top-cards.s3.eu-north-1.amazon...    272792
# 5   https://fantasy-top-cards.s3.eu-north-1.amazon...    197263
# 6   https://fantasy-top-cards.s3.eu-north-1.amazon...    262872
# 7   https://fantasy-top-cards.s3.eu-north-1.amazon...    434003
# 8   https://fantasy-top-cards.s3.eu-north-1.amazon...    191364
# 9   https://fantasy-top-cards.s3.eu-north-1.amazon...    436924
# 10  https://fantasy-top-cards.s3.eu-north-1.amazon...    475603
# 11  https://fantasy-top-cards.s3.eu-north-1.amazon...    387335
# 12  https://fantasy-top-cards.s3.eu-north-1.amazon...    319668
# 13  https://fantasy-top-cards.s3.eu-north-1.amazon...    436850
# 14  https://fantasy-top-cards.s3.eu-north-1.amazon...    341173
# 15  https://fantasy-top-cards.s3.eu-north-1.amazon...    375498
# 16  https://fantasy-top-cards.s3.eu-north-1.amazon...    495199
# 17  https://fantasy-top-cards.s3.eu-north-1.amazon...    434452
# 18  https://fantasy-top-cards.s3.eu-north-1.amazon...     34063
# 19  https://fantasy-top-cards.s3.eu-north-1.amazon...    390290
# 20  https://fantasy-top-cards.s3.eu-north-1.amazon...    486067
# 21  https://fantasy-top-cards.s3.eu-north-1.amazon...     85472
# 22  https://fantasy-top-cards.s3.eu-north-1.amazon...    495695
# 23  https://fantasy-top-cards.s3.eu-north-1.amazon...    486109
# 24  https://fantasy-top-cards.s3.eu-north-1.amazon...    460932
#
#         hero_rarity_index              hero_id              hero_name  \
# 0   1585936726370852865_3  1585936726370852865                PreRich
# 1    954015928924057601_3   954015928924057601        _gabrielShapir0
# 2   1492434155405287424_3  1492434155405287424  Pacman | Blur + Blast
# 3    906234475604037637_4   906234475604037637              K A L E O
# 4    873190778910253056_4   873190778910253056              KJ Crypto
# 5             618539620_3            618539620                   Iced
# 6   1635676907529285642_3  1635676907529285642        Hugo Martingale
# 7   1356386110847377408_3  1356386110847377408                foobar/
# 8   1093242943127932930_4  1093242943127932930               ciniz 👁️
# 9            1107518478_4           1107518478                 Yano 🟪
# 10  1408762516969201671_3  1408762516969201671           yieldfarming
# 11   886765719391789057_3   886765719391789057        zac.eth 🧙🏻‍♂️♦️
# 12  1400381995558047749_3  1400381995558047749                  apix🎮
# 13  1310378599984148480_4  1310378599984148480                   Minh
# 14   954015928924057601_4   954015928924057601        _gabrielShapir0
# 15  1404603419101306881_3  1404603419101306881                 kmoney
# 16   712457848874086400_4   712457848874086400                     qw
# 17  1356386110847377408_3  1356386110847377408                foobar/
# 18            618539620_4            618539620                   Iced
# 19  1432686185810432010_3  1432686185810432010               AiRev //
# 20  1408762516969201671_3  1408762516969201671           yieldfarming
# 21  1354867416430501890_4  1354867416430501890                 mikado
# 22            588569122_4            588569122         wallstreetbets
# 23   720313843021385728_3   720313843021385728        kipit | fan/acc
# 24  1350996311777161219_3  1350996311777161219                DCF GOD
#
#         hero_handle                             hero_profile_image_url  \
# 0         0xprerich  https://pbs.twimg.com/profile_images/181170797...
# 1          lex_node  https://pbs.twimg.com/profile_images/176506460...
# 2        PacmanBlur  https://pbs.twimg.com/profile_images/149957170...
# 3       CryptoKaleo  https://pbs.twimg.com/profile_images/160604173...
# 4   koreanjewcrypto  https://pbs.twimg.com/profile_images/181511037...
# 5         IcedKnife  https://pbs.twimg.com/profile_images/165074681...
# 6    HugoMartingale  https://pbs.twimg.com/profile_images/179487982...
# 7          0xfoobar  https://pbs.twimg.com/profile_images/174582432...
# 8       screentimes  https://pbs.twimg.com/profile_images/180397688...
# 9     JasonYanowitz  https://pbs.twimg.com/profile_images/176861934...
# 10      delucinator  https://pbs.twimg.com/profile_images/158462563...
# 11           zacxbt  https://pbs.twimg.com/profile_images/176094275...
# 12         apixtwts  https://pbs.twimg.com/profile_images/166312830...
# 13     MINHxDYNASTY  https://pbs.twimg.com/profile_images/178871858...
# 14         lex_node  https://pbs.twimg.com/profile_images/176506460...
# 15        kmoney_69  https://pbs.twimg.com/profile_images/178502389...
# 16           QwQiao  https://pbs.twimg.com/profile_images/177449751...
# 17         0xfoobar  https://pbs.twimg.com/profile_images/174582432...
# 18        IcedKnife  https://pbs.twimg.com/profile_images/165074681...
# 19    ParallelAiRev  https://pbs.twimg.com/profile_images/171988942...
# 20      delucinator  https://pbs.twimg.com/profile_images/158462563...
# 21         0xMikado  https://pbs.twimg.com/profile_images/179408601...
# 22   wallstreetbets  https://pbs.twimg.com/profile_images/181297406...
# 23          0xKipit  https://pbs.twimg.com/profile_images/179408701...
# 24           dcfgod  https://pbs.twimg.com/profile_images/154630167...
#
#     hero_followers_count  hero_stars  hero_fantasy_score  hero_current_rank  \
# 0                  15568           5          673.468342                 39
# 1                  47194           5          558.588783                 70
# 2                  60294           3          382.238589                113
# 3                 642260           6          731.187600                 28
# 4                 137404           3          387.578233                110
# 5                 311853           6          530.012894                 79
# 6                  14263           4          525.959152                 81
# 7                 155394           2          210.947858                155
# 8                  74095           5          599.511482                 58
# 9                 111219           4          665.516454                 42
# 10                 22757           6          602.386527                 57
# 11                  9982           4          521.227869                 83
# 12                 20277           4          446.301320                100
# 13                 26159           3          372.268968                115
# 14                 47194           5          558.588783                 70
# 15                130399           6          598.668638                 59
# 16                144563           5          625.521905                 50
# 17                155394           2          210.947858                155
# 18                311853           6          530.012894                 79
# 19                 29560           3          296.365796                142
# 20                 22757           6          602.386527                 57
# 21                 20614           2          301.764403                140
# 22                773762           7          898.674415                  5
# 23                 19715           3          306.654236                137
# 24                 87373           4          457.045972                 96
#
#     tournament_fantasy_score  tournament_current_rank  tournament_views  \
# 0                          0                        0                 0
# 1                          0                        0                 0
# 2                          0                        0                 0
# 3                          0                        0                 0
# 4                          0                        0                 0
# 5                          0                        0                 0
# 6                          0                        0                 0
# 7                          0                        0                 0
# 8                          0                        0                 0
# 9                          0                        0                 0
# 10                         0                        0                 0
# 11                         0                        0                 0
# 12                         0                        0                 0
# 13                         0                        0                 0
# 14                         0                        0                 0
# 15                         0                        0                 0
# 16                         0                        0                 0
# 17                         0                        0                 0
# 18                         0                        0                 0
# 19                         0                        0                 0
# 20                         0                        0                 0
# 21                         0                        0                 0
# 22                         0                        0                 0
# 23                         0                        0                 0
# 24                         0                        0                 0
#
#    tournament_type
# 0           Silver
# 1           Silver
# 2           Silver
# 3           Silver
# 4           Silver
# 5           Silver
# 6           Silver
# 7           Silver
# 8           Silver
# 9           Silver
# 10          Silver
# 11          Silver
# 12          Silver
# 13          Silver
# 14          Silver
# 15          Silver
# 16          Silver
# 17          Silver
# 18          Silver
# 19          Silver
# 20          Silver
# 21          Silver
# 22          Silver
# 23          Silver
# 24          Silver

# %% [markdown]
# ## Portfolio Bits

# %%
# Assuming 'dataframes' is a dictionary with your DataFrames and 'final_merged_df' is your DataFrame
portfolio_df = dataframes['portfolio']
final_df = final_merged_df

# Step 1: Extract the last digit from 'hero_rarity_index' and create 'rarity' column
portfolio_df['rarity'] = portfolio_df['hero_rarity_index'].str[-1]

# Step 2: Remove 'hero_rarity_index' column
portfolio_df = portfolio_df.drop(columns=['hero_rarity_index'])

# Step 3: Add 'lowest price' column
def get_lowest_price(row, final_df):
    rarity_column = f'rarity{row["rarity"]}_lowest_price'
    matched_row = final_df[final_df['hero_id'] == row['hero_id']]
    if not matched_row.empty:
        return matched_row.iloc[0][rarity_column]
    return None

portfolio_df['lowest price'] = portfolio_df.apply(get_lowest_price, final_df=final_df, axis=1)

# Step 4: Add 'last price' column
def get_last_price(row, final_df):
    rarity_column = f'rarity{row["rarity"]}lastSalePrice'
    matched_row = final_df[final_df['hero_id'] == row['hero_id']]
    if not matched_row.empty:
        return matched_row.iloc[0][rarity_column]
    return None

portfolio_df['last price'] = portfolio_df.apply(get_last_price, final_df=final_df, axis=1)

# Update the dictionary with the modified DataFrame
dataframes['portfolio'] = portfolio_df

# Display the updated DataFrame
print(portfolio_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Python310\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rarity3_lowest_price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 19
#      16         return matched_row.iloc[0][rarity_column]
#      17     return None
# ---> 19 portfolio_df['lowest price'] = portfolio_df.apply(get_lowest_price, final_df=final_df, axis=1)
#      21 # Step 4: Add 'last price' column
#      22 def get_last_price(row, final_df):
#
# File C:\Python310\lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File C:\Python310\lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File C:\Python310\lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File C:\Python310\lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[21], line 16, in get_lowest_price(row, final_df)
#      14 matched_row = final_df[final_df['hero_id'] == row['hero_id']]
#      15 if not matched_row.empty:
# ---> 16     return matched_row.iloc[0][rarity_column]
#      17 return None
#
# File C:\Python310\lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File C:\Python310\lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File C:\Python310\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'rarity3_lowest_price'

# %%
# Step 1: Create new columns for the products
portfolio_df['total_value_lowest_price'] = portfolio_df['lowest price'] * portfolio_df['cards_number']
portfolio_df['total_value_last_price'] = portfolio_df['last price'] * portfolio_df['cards_number']

# Step 2: Calculate the sums
total_lowest_price_value = portfolio_df['total_value_lowest_price'].sum()
total_last_price_value = portfolio_df['total_value_last_price'].sum()

# Display the results
print(f"Total Lowest Price Value: {total_lowest_price_value}")
print(f"Total Last Price Value: {total_last_price_value}")
# Out:
# Total Lowest Price Value: 2.6838221291111006
# Total Last Price Value: 2.3893410904999994
